# %%
import pandas as pd
import numpy as np
import os
import random
import re

# %% [markdown]
# ### Path to train and test data

# %%
test_path = 'data/balanced_test_set.csv'
train_path = 'data/train_set.csv'

# %%
train_data = pd.read_csv(train_path, delimiter=',', quotechar='|', encoding="utf8")
train_data.head()
# Out:
#                                                Tweet  Sentiment
# 0  <ID>  <ID> Då missförstår du mig Hålla låg pro...          0
# 1  <ID> om drivkraften bara är pengar så förstår jag          0
# 2  <ID>  <ID> Här kan ni köpa in er i mitt andels...          0
# 3  Föredömligt av @FolksamMedia att inte invester...          1
# 4  Rutger Arnhults privata bolag emitterar obliga...          0

# %%
test_data = pd.read_csv(test_path, delimiter=',', quotechar='|', encoding="utf8")
test_data.head()
# Out:
#                                                Tweet  Sentiment
# 0              <ID>  <ID> jaaa med Calle och Hobbe p          1
# 1                  ÅH VAD JAG ÄLSKAR ATT VARA KVINNA          1
# 2  Drygt en vecka kvar rösta i kyrkovalet gärna p...          1
# 3  En lite bra tråd om våld och nazister och sånt...          1
# 4  På väg hem efter en fantastiskt trevlig AW med...          1

# %% [markdown]
# ## Sampling
# ### Do we want to under-sample the majority classes, creating a balanced training set where randomly selected tweets from the majority classes are extracted to match the minority class? Or do we want to under-sample the majority class(es) and over-sample the minority class(es)
#
# #### -1 = negative  |  0 = neutral  |  1 = positive

# %%
train_data.groupby('Sentiment').count()
# Out:
#            Tweet
# Sentiment
# -1          2551
#  0          5820
#  1          2703

# %%
# ---- Enter True / False ----
# ---- if False, new varible must be larger than smallest and smaller than largest in table above. -----
only_under_sample = False
no_sampling = False # use ALL training data without any balancing.

new = 3100

if only_under_sample:
    print('Under-sampling, only.')
else:
    print('Under- and over-sampling to create a balanced training set with {} tweets in each class'.format(new))
# Out:
# Under- and over-sampling to create a balanced training set with 3100 tweets in each class

# %%
pos = []
neg = []
neu = []
for tweet_tuple in train_data.iterrows():
    tweet = tweet_tuple[1]['Tweet']
    sentiment = int(tweet_tuple[1]['Sentiment'])

    if sentiment == -1:
        neg.append([tweet, sentiment])

    if sentiment == 0:
        neu.append([tweet, sentiment])

    if sentiment == 1:
        pos.append([tweet, sentiment])
            
len_neu = len(neu)
len_neg = len(neg)
len_pos = len(pos)
            
#print(len_neu, ' Neutral')
#print(len_neg, ' Negative')
#print(len_pos, ' Positive')

minimi = min(len_neg, len_neu, len_pos)

if only_under_sample and not no_sampling:
    print('Under-sampling a balanced training data set')
    
    print('Smallest class size: ', minimi)

    np.random.shuffle(pos)
    np.random.shuffle(neg)
    np.random.shuffle(neu)
    
    print('Shuffling new dataset...')
    balanced_data = np.vstack((pos[:minimi], neu[:minimi], neg[:minimi]))

    np.random.shuffle(balanced_data)
    print('Size of training set, with {} in each class:'.format(minimi))
    print(len(balanced_data))
    
elif not only_under_sample and not no_sampling:
    print('Under- and over-sampling a balanced training data set')
    
    remaining_pos = new - len(pos)
    remaining_neg = new - len(neg)

    pos_copy = pos.copy()
    neg_copy = neg.copy()

    upsampled_pos = []
    upsampled_neg = []


    for i in range(remaining_pos):
        rand_id = random.randint(0, len(pos_copy) - 1)
        upsampled_pos.append(pos_copy.pop(rand_id))

    for i in range(remaining_neg):
        rand_id = random.randint(0, len(neg_copy) - 1)
        upsampled_neg.append(neg_copy.pop(rand_id))
        
    pos = np.vstack((pos, upsampled_pos))
    neg = np.vstack((neg, upsampled_neg))

    np.random.shuffle(pos)
    np.random.shuffle(neg)
    np.random.shuffle(neu)
    
    # Note that this line must be changed if the distribution of the training data shifts.
    # It now assumes that pos and neg is over-sampled and that neu is under-sampled!
    balanced_data = np.vstack((pos, neu[:new], neg))
    
    print('Shuffling new dataset...')
    np.random.shuffle(balanced_data)
    print('Size of training set, with {} in each class:'.format(new))
    print(len(balanced_data))
    
elif not only_under_sample and no_sampling:
    balanced_data = np.vstack((pos, neu, neg))
    print('Including ALL available training data <-- unbalanced')
    np.random.shuffle(balanced_data)
    print('size:')
    print(len(balanced_data))
# Out:
# Under- and over-sampling a balanced training data set
# Shuffling new dataset...
# Size of training set, with 3100 in each class:
# 9300

# %% [markdown]
# ### Separate tweets from labels

# %%
train_X = [pair[0] for pair in balanced_data]
train_Y = [int(pair[1]) for pair in balanced_data]

test_X = test_data['Tweet'].tolist()
test_Y = test_data['Sentiment'].tolist()

# %% [markdown]
# ### Helper methods

# %%
def reduce_lengthening(text):
    '''
    An ad-hoc spellcheck. No swedish words contains more than two identical characters
    in a sequence. This method finds those and shortens them to two - irregardless of
    whether it's a noun or whatever. ALL occurrences are reduced to only two in order to
    ensure words that are commonly emphazised, i.e såååååå, are included in the vocabulary.
    '''
    pattern = re.compile(r"(.)\1{2,}")
    return pattern.sub(r"\1\1", text)

# %% [markdown]
# ### Clean and pre-process each tweet. Stemming and stop-word removal is removed from pre-processing stage after empirical findings.

# %%
def cleanTweet(tweet):
    
    # Here we have each tweet. Process and add to file.

    # Replaces various URLs with "<URL>"
    filtered = re.sub(r"http\S+", " <URL>", tweet)

    # Replace mentions with anonymous <ID>
    filtered = re.sub(r"@\S+", " <ID>", filtered)

    # Replace haschtags with anonymous <HASCHTAG>
    filtered = re.sub(r"#\S+", " <HASCHTAG>", filtered)

    filtered = reduce_lengthening(filtered)

    # Replace each '-' and '/' with ' - ' and ' / ' because they are common in text
    filtered = filtered.replace("-", " - ")
    filtered = filtered.replace("/", " / ")

    filtered = re.sub('[\'&]+', '', filtered)

    #Remove non-alpha numerical and <> from tweet
    filtered = re.sub('[^0-9a-zA-Z åäöÅÄÖ<>]+', ' ', filtered)

    prev = ''
    sentence = ''
    for word in filtered.split():
        word = word.strip().lower()
        
        # Here you would stem the word

        if not (word == prev and (word == '<id>' or word == '<haschtag>' or word == '<url>')) and not word == 'amp':
            # Here you would ensure the word is not a stop-word
            sentence = sentence + ' ' + word
        prev = word

    return sentence


train_cleaned_tweets = []
for tweet in train_X:
    tweet = cleanTweet(tweet)
    #print(tweet)
    train_cleaned_tweets.append(tweet)
    
test_cleaned_tweets = []
for tweet in test_X:
    tweet = cleanTweet(tweet)
    #print(tweet)
    test_cleaned_tweets.append(tweet)

# %% [markdown]
# ### Ensure alll dimensions add up

# %%
print(len(train_cleaned_tweets), len(train_Y))
print(len(test_cleaned_tweets), len(test_Y))
# Out:
# 9300 9300
# 1008 1008

# %%
#count = 0
#for i in range(len(test_cleaned_tweets)):
#    for tweet in train_cleaned_tweets:
#        if tweet == test_cleaned_tweets[i]:
#            print(tweet)
#            print(test_cleaned_tweets[i])
#            count += 1
#print(count)

# %%
def createVocabulary(text):
    dic = {}
    for line in text:
        for word in line.split():
            word = word.strip() #Removes blanks and '\n' from the end when needed.
            dic[word] = dic.get(word, 0) + 1
                
    return dic
vocabulary = createVocabulary(train_cleaned_tweets)

# %%
print('Number of unique words:')
print(len(vocabulary))
# Out:
# Number of unique words:
# 18804

# %% [markdown]
# ### word2index is a dictionary that maps a word to an index, i.e corresponding place in input vector
# ### index2word is a dictionary that maps an index (from the input vector-space) to a word.

# %%
import collections

def createWordMapper(vocabulary, vocabSize):
    '''
    Takes a vocabulary (dictionary) of variable size and a desired vocabulary size as input. 
    Returns the two mappers: word2index & index2word.
    
    NB, when the mappers are created we don't use the original vocabulary anymore (i think).
    '''

    # Order the dictinoary in order to extract the most frequent
    sortedVocabulary = sorted(vocabulary.items(), key=lambda kv: kv[1], reverse=True)

    word2index = collections.OrderedDict()
    index2word = collections.OrderedDict()

    for i in range(vocabSize):
        index = len(word2index)
        word = sortedVocabulary[i][0]
        
        word2index[word] = index
        index2word[index] = word
    word2index['UNK'] = index + 1
    index2word[index + 1] = 'UNK'
            
    return word2index, index2word
    

vocabularySize = len(vocabulary) # Include ALL words in the vocabulary-mappers
word2index, index2word = createWordMapper(vocabulary, vocabularySize - 1)

print('Size of vocabulary: ' +str(len(word2index)))
print('Maximum size of vocabulary: ' + str(len(vocabulary)))
# Out:
# Size of vocabulary: 18804
# Maximum size of vocabulary: 18804

# %% [markdown]
# ### Ilustration

# %%
test = word2index.get('bäst')
print('index: ', test)
print('word: ', index2word.get(test))
# Out:
# index:  341
# word:  bäst

# %% [markdown]
# ### Create input vectors with BoW approach

# %%
def getVector(tweet):
    vec = np.zeros([vocabularySize, 1])
    for word in tweet.split():
        if word2index.get(word) is not None:
            vec[word2index.get(word)] += 1
        else:
            vec[word2index.get('UNK')] += 1
    return vec
            
train_x_vectorized = []
for tweet in train_cleaned_tweets:
    train_x_vectorized.append(getVector(tweet))
    
test_x_vectorized = []
for tweet in test_cleaned_tweets:
    test_x_vectorized.append(getVector(tweet))

# %%
# Remove unnecessary 1-dimension which np creates above
train_x_vectorized = np.squeeze(train_x_vectorized)
test_x_vectorized = np.squeeze(test_x_vectorized)

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Linear SVM

# %%
from sklearn.svm import LinearSVC
clf_linear = LinearSVC(C=1, max_iter = 10000, verbose=9)

# %%
clf_linear.fit(train_x_vectorized, train_Y)
# Out:
# [LibLinear]
# LinearSVC(C=1, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=10000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=9)

# %%
print("Detailed classification report:")
print()
print("The model is trained on the full development set.")
print("The scores are computed on the full evaluation set.")

y_true, y_pred = test_Y, clf_linear.predict(test_x_vectorized)

print(classification_report(y_true, y_pred))
print()
print('Accuracy on test/evaluation set: ', accuracy_score(y_true, y_pred))
print()
print('Confusion matrix:')
print(confusion_matrix(y_true, y_pred))
# Out:
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#               precision    recall  f1-score   support
#
#           -1       0.70      0.49      0.58       336
#            0       0.52      0.68      0.59       336
#            1       0.70      0.69      0.70       336
#
#    micro avg       0.62      0.62      0.62      1008
#    macro avg       0.64      0.62      0.62      1008
# weighted avg       0.64      0.62      0.62      1008
#
#
# Accuracy on test/evaluation set:  0.6220238095238095
#
# Confusion matrix:
# [[166 125  45]
#  [ 54 228  54]
#  [ 16  87 233]]

# %% [markdown]
# ### Training a calibrated classifier using platt-scaling, to produce probabilities per class

# %%
from sklearn.calibration import CalibratedClassifierCV

clf_calibrated = CalibratedClassifierCV(clf_linear, cv=5) 
clf_calibrated.fit(train_x_vectorized, train_Y)
y_proba = clf_calibrated.predict_proba(test_x_vectorized)
# Out:
# [LibLinear][LibLinear][LibLinear][LibLinear][LibLinear]

# %% [markdown]
# ### Print tweet, probabilities and prediction per tweet in test set
# #### Probabilities: [prob_neg, prob_neu, prob_pos]

# %%
for index, i in enumerate(test_X):
    label = y_true[index]
    pred = y_pred[index]

    print()
    print('Original tweet:')
    print(i)
    print()
    print('Preprocessed tweet:')
    print(test_cleaned_tweets[index])
    print()
    print('Probabilities:')
    print('    neg \t neu \t   pos')
    print(y_proba[index])
    print()
    print('Prediction: \t', pred)
    print('label \t\t', label)
    print()
    print('-------------------------')
# Out:
# Original tweet:
# <ID>  <ID> jaaa med Calle och Hobbe p
#
# Preprocessed tweet:
#  <id> jaa med calle och hobbe p
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.15624423 0.37441376 0.469342  ]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# ÅH VAD JAG ÄLSKAR ATT VARA KVINNA
#
# Preprocessed tweet:
#  åh vad jag älskar att vara kvinna
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.04907227 0.14262149 0.80830624]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Drygt en vecka kvar rösta i kyrkovalet gärna på Visk till  <URL>
#
# Preprocessed tweet:
#  drygt en vecka kvar rösta i kyrkovalet gärna på visk till <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.02305637 0.58103544 0.39590819]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# En lite bra tråd om våld och nazister och sånt från en amerikans kontext. <URL>
#
# Preprocessed tweet:
#  en lite bra tråd om våld och nazister och sånt från en amerikans kontext <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.20111808 0.14846935 0.65041257]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# På väg hem efter en fantastiskt trevlig AW med <ID> och <ID> Det här gör vi om snart igen! Sov gott sen
#
# Preprocessed tweet:
#  på väg hem efter en fantastiskt trevlig aw med <id> och <id> det här gör vi om snart igen sov gott sen
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.00284138 0.04207717 0.95508144]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
#  <ID> Jag blev mer taggad av att kolla statsen. Aldrig kul att stå vid sidan, men gillar hetsen i de här båda matchserierna.
#
# Preprocessed tweet:
#  <id> jag blev mer taggad av att kolla statsen aldrig kul att stå vid sidan men gillar hetsen i de här båda matchserierna
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.04291832 0.13011685 0.82696482]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Grattis! Första 9-5?
#
# Preprocessed tweet:
#  <id> grattis första 9 5
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.11036025 0.22376033 0.66587942]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Hahaha det är heeeelt stört!!!
#
# Preprocessed tweet:
#  <id> hahaha det är heelt stört
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.13952353 0.25001043 0.61046603]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Einar är överallt! Kul att se. Emil Larsson är en kanonvärvning. Jonas Berglund gör ett riktigt fint centerjobb. Sp… <URL>
#
# Preprocessed tweet:
#  einar är överallt kul att se emil larsson är en kanonvärvning jonas berglund gör ett riktigt fint centerjobb sp <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.04910668 0.10239    0.84850332]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Håller med Mycket vilja från start Gillat honom från första början
#
# Preprocessed tweet:
#  <id> håller med mycket vilja från start gillat honom från första början
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.14629809 0.16183088 0.69187104]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> det håller jag med om! själv gillar jag helt könsneutrala namn. t.ex Lo.
#
# Preprocessed tweet:
#  <id> det håller jag med om själv gillar jag helt könsneutrala namn t ex lo
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.02432122 0.38083625 0.59484252]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Bra kväll ! HV leder med 4-1 <HASCHTAG> och Mullsjö leder med 9-5 <HASCHTAG>
#
# Preprocessed tweet:
#  bra kväll hv leder med 4 1 <haschtag> och mullsjö leder med 9 5 <haschtag>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.03398906 0.07063146 0.89537948]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID>  <ID>  <ID> Så bra sving har han inte va
#
# Preprocessed tweet:
#  <id> så bra sving har han inte va
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.22830017 0.24790234 0.5237975 ]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Jag hade uppskattat om Emil ser en video av 01 och utvärderar sin insats
#
# Preprocessed tweet:
#  jag hade uppskattat om emil ser en video av 01 och utvärderar sin insats
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.18787903 0.20348792 0.60863304]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Tack för vårt viktiga möte i dag! <ID>
#
# Preprocessed tweet:
#  tack för vårt viktiga möte i dag <id>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.05851012 0.24392165 0.69756823]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# @annikamarkovic @ICC_Sweden @RagnSells_Group @RagnSells_AB @FolksamMedia @iccwbo @Jernkontoret @IVLSvenskaMiljo @handelskammare @SweChamNL @ZwedeninNL Låt oss resonera om detta, det är mycket intressant för oss.
#
# Preprocessed tweet:
#  <id> låt oss resonera om detta det är mycket intressant för oss
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.20191792 0.19231994 0.60576214]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Kan ju ha med vädret att göra När äntligen solen visar sig i söder vilk man inte åka tillbaka till snön
#
# Preprocessed tweet:
#  <id> kan ju ha med vädret att göra när äntligen solen visar sig i söder vilk man inte åka tillbaka till snön
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.240116   0.10469946 0.65518454]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Synd värt ett försök
#
# Preprocessed tweet:
#  <id> synd värt ett försök
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.34851497 0.34123529 0.31024974]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Brynäs har alltså ledningen med 4-1 just nu - och de fortsätter pressa på! <HASCHTAG>
#
# Preprocessed tweet:
#  brynäs har alltså ledningen med 4 1 just nu och de fortsätter pressa på <haschtag>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.4701714  0.24561505 0.28421355]
#
# Prediction: 	 -1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Den som lägger lite tid på sin hälsa och fysik bör inte oroa sig för att jobba länge i livet.
#
# Preprocessed tweet:
#  den som lägger lite tid på sin hälsa och fysik bör inte oroa sig för att jobba länge i livet
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.34899697 0.58248699 0.06851603]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Bra morgonkontroll! <HASCHTAG> <URL>
#
# Preprocessed tweet:
#  bra morgonkontroll <haschtag> <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.1079504  0.24845817 0.64359143]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Fun fact: Vi Dabbar i dansen på insparken på mitt universitet i år x) P.S: Inte jag som var dansansvarig!!
#
# Preprocessed tweet:
#  <id> fun fact vi dabbar i dansen på insparken på mitt universitet i år x p s inte jag som var dansansvarig
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.16954714 0.7527052  0.07774766]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Kalendertävlingen gör bejublad comeback! <URL>
#
# Preprocessed tweet:
#  kalendertävlingen gör bejublad comeback <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.19279363 0.49834824 0.30885813]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# <URL> Ta ställning och visa att barn inte är till salu.
#
# Preprocessed tweet:
#  <url> ta ställning och visa att barn inte är till salu
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.67674342 0.24062842 0.08262816]
#
# Prediction: 	 -1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Du är grym Tack Annika
#
# Preprocessed tweet:
#  <id> du är grym tack annika
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.08912694 0.09291022 0.81796285]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# @HansSterte @SPP_sverige @SkandiaSE Det ska jag berätta för dig när vi se över en lunch. Jag gillar Staffan och Maria.
#
# Preprocessed tweet:
#  <id> det ska jag berätta för dig när vi se över en lunch jag gillar staffan och maria
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.09139897 0.45386761 0.45473342]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Det inger hopp
#
# Preprocessed tweet:
#  <id> det inger hopp
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.38117358 0.2306956  0.38813082]
#
# Prediction: 	 -1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Om en minut öppnar arenan och denna tomma stilla ishall förvandlas till en känslofylld taggad hemmaborg! Nu Gävlar… <URL>
#
# Preprocessed tweet:
#  om en minut öppnar arenan och denna tomma stilla ishall förvandlas till en känslofylld taggad hemmaborg nu gävlar <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.31600018 0.26205622 0.4219436 ]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Måste genast lokalisera närmsta blodbuss och testa känns det som
#
# Preprocessed tweet:
#  <id> måste genast lokalisera närmsta blodbuss och testa känns det som
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.38601154 0.33889924 0.27508922]
#
# Prediction: 	 -1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> du måste ha världens bästa syster
#
# Preprocessed tweet:
#  <id> du måste ha världens bästa syster
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.20594241 0.15207153 0.64198606]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Fantastiskt roligt med <ID> och Per Svensson vid rodret! <URL>
#
# Preprocessed tweet:
#  fantastiskt roligt med <id> och per svensson vid rodret <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.05766965 0.06002036 0.88230999]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Härligt med första slutspelsmatchen live för säsongen På torsdag MalmöIKSU Hoppas på samma kamp där  <HASCHTAG>
#
# Preprocessed tweet:
#  härligt med första slutspelsmatchen live för säsongen på torsdag malmöiksu hoppas på samma kamp där <haschtag>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.0394049  0.13574798 0.82484712]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Vore ju superkul!!
#
# Preprocessed tweet:
#  <id> vore ju superkul
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.21378237 0.31914103 0.46707659]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
#  <ID> Flummigt, men kul.
#
# Preprocessed tweet:
#  <id> flummigt men kul
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.14585059 0.22273737 0.63141204]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Ace ett av tidernas bästa album  <URL>
#
# Preprocessed tweet:
#  ace ett av tidernas bästa album <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.05392514 0.27548211 0.67059275]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Bonnier får starta en med dig nu. Älskar din entusiasm och nyfikenhet.
#
# Preprocessed tweet:
#  <id> bonnier får starta en med dig nu älskar din entusiasm och nyfikenhet
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.05617738 0.28552559 0.65829703]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Jag ska på överraskningsfest ikväll Alltså festen är bara en överraskning för mig eftersom han glömt att berätta om den för mig
#
# Preprocessed tweet:
#  jag ska på överraskningsfest ikväll alltså festen är bara en överraskning för mig eftersom han glömt att berätta om den för mig
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.39639628 0.51255236 0.09105136]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Spännande!
#
# Preprocessed tweet:
#  <id> spännande
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.17152734 0.30152256 0.52695011]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Plötsligt händer det
#
# Preprocessed tweet:
#  <id> plötsligt händer det
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.14075265 0.35750823 0.50173913]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Hahaha! Dansbandskanalen Jul finns ju dock nu såg jag. På tiden!
#
# Preprocessed tweet:
#  <id> hahaha dansbandskanalen jul finns ju dock nu såg jag på tiden
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.10130177 0.48833415 0.41036408]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
#  <ID> vad han sa var "as if anyone writes jokes in base 13". Jag tycker dock det vore roligt som fan <ID>
#
# Preprocessed tweet:
#  <id> vad han sa var as if anyone writes jokes in base 13 jag tycker dock det vore roligt som fan <id>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.16658682 0.17413961 0.65927357]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Jo då, vi hade en kanonkväll i #Eftersnack från @skandiase trädgård i #Almedalen och i @expressentv. I morgon är vi tillbaka, 19.00-20.15. Samma plats, nya gäster. https://t.co/DmyILvVM3i
#
# Preprocessed tweet:
#  jo då vi hade en kanonkväll i <haschtag> från <id> trädgård i <haschtag> och i <id> i morgon är vi tillbaka 19 00 20 15 samma plats nya gäster <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.0349518  0.84577624 0.11927197]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Portalparagrafen från <HASCHTAG> om att huvudmännen har ett ansvar att minska skolsegregationen är mkt bra <HASCHTAG>
#
# Preprocessed tweet:
#  portalparagrafen från <haschtag> om att huvudmännen har ett ansvar att minska skolsegregationen är mkt bra <haschtag>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.2137116  0.21381977 0.57246863]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Helt rätt målvaktsval av Färjestad  <ID>
#
# Preprocessed tweet:
#  helt rätt målvaktsval av färjestad <id>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.19628971 0.38505784 0.41865245]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> tack snälla Ska njuta varje sekund
#
# Preprocessed tweet:
#  <id> tack snälla ska njuta varje sekund
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.19511942 0.07316802 0.73171256]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Pantern borde få spela i SHL med den publiksiffran Flytta upp dom direkt
#
# Preprocessed tweet:
#  pantern borde få spela i shl med den publiksiffran flytta upp dom direkt
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.43850969 0.45694767 0.10454264]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Så j-a GÖTT! <URL>
#
# Preprocessed tweet:
#  så j a gött <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.12988863 0.22477277 0.64533859]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Tänk att det är så roligt att titta bakom kulisserna! <ID> på Bonniers Konsthall <URL>
#
# Preprocessed tweet:
#  tänk att det är så roligt att titta bakom kulisserna <id> på bonniers konsthall <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.03817686 0.54513909 0.41668405]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Låg och snarkade Men det låter ju som en story av guds nåde
#
# Preprocessed tweet:
#  <id> låg och snarkade men det låter ju som en story av guds nåde
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.41838321 0.35105398 0.23056281]
#
# Prediction: 	 -1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Vackert. Värdigt. Fint. <URL>
#
# Preprocessed tweet:
#  vackert värdigt fint <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.03161187 0.10562404 0.86276409]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
#  Vad fantastiskt det är att jag en söndag kan beställa hundfoder, på mobilen, för leverans ända fram till dörren! <HASCHTAG>
#
# Preprocessed tweet:
#  vad fantastiskt det är att jag en söndag kan beställa hundfoder på mobilen för leverans ända fram till dörren <haschtag>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.09056207 0.48013477 0.42930316]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> stort tack för uppmuntran! :)
#
# Preprocessed tweet:
#  <id> stort tack för uppmuntran
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.07371407 0.16085603 0.7654299 ]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Inte en dag för tidigt Blev oerhört glad när jag läste detta
#
# Preprocessed tweet:
#  <id> inte en dag för tidigt blev oerhört glad när jag läste detta
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.11432198 0.40025543 0.48542259]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> B.Orr. Mäktigt snickarnamn också.
#
# Preprocessed tweet:
#  <id> b orr mäktigt snickarnamn också
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.23408831 0.27983786 0.48607383]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID>  <ID> Er nya politik med samordnare innovationskatapulter traineejobb industrikansler har ju gått så bra
#
# Preprocessed tweet:
#  <id> er nya politik med samordnare innovationskatapulter traineejobb industrikansler har ju gått så bra
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.13367758 0.51814633 0.34817609]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID>  <ID> Yes bästa duon
#
# Preprocessed tweet:
#  <id> yes bästa duon
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.04120645 0.1896279  0.76916565]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> ja det är vi överens om
#
# Preprocessed tweet:
#  <id> ja det är vi överens om
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.33094504 0.5105092  0.15854576]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Tack Familjen Skott i Estland för Årets påsklamm! (ping Lennart Skott)
#
# Preprocessed tweet:
#  tack familjen skott i estland för årets påsklamm ping lennart skott
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.15277666 0.46230731 0.38491603]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Hasse Borg gjorde ett par riktigt sjuka fönster i MFF
#
# Preprocessed tweet:
#  <id> hasse borg gjorde ett par riktigt sjuka fönster i mff
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.3357821  0.59257447 0.07164343]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Hahaha Nej Det är 100 rätt
#
# Preprocessed tweet:
#  <id> hahaha nej det är 100 rätt
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.36356309 0.22635501 0.4100819 ]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Men annars har svenskar det väldigt bra i gemen. Normalt att ha ledigt 6 v på sommaren på ett sommarställe man bor gratis på.
#
# Preprocessed tweet:
#  <id> men annars har svenskar det väldigt bra i gemen normalt att ha ledigt 6 v på sommaren på ett sommarställe man bor gratis på
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.12654594 0.43383051 0.43962355]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Debatt Säkerhetsrådets fördömande av Israeliska bosättningar på ockuperad mark kan ge Palestina ett gott nytt år  <URL>
#
# Preprocessed tweet:
#  debatt säkerhetsrådets fördömande av israeliska bosättningar på ockuperad mark kan ge palestina ett gott nytt år <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.03220538 0.34591093 0.62188369]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> kan ni snälla komma och stötta
#
# Preprocessed tweet:
#  <id> kan ni snälla komma och stötta
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.37544656 0.36509781 0.25945564]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# 11 Du kan alltid räkna med mig när det kommer till att äta upp din mat Så lämna mig inte utan uppsikt inte ens när du bara ska ner till gt
#
# Preprocessed tweet:
#  11 du kan alltid räkna med mig när det kommer till att äta upp din mat så lämna mig inte utan uppsikt inte ens när du bara ska ner till gt
#
# Probabilities:
#     neg 	 neu 	   pos
# [5.15020164e-01 4.84575006e-01 4.04830578e-04]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# HURRA för Bengt Vi ses väl på söndag Åh stiftsgårds vänner kommer vara där Är du medlem  <HASCHTAG>  <HASCHTAG>  <URL>
#
# Preprocessed tweet:
#  hurra för bengt vi ses väl på söndag åh stiftsgårds vänner kommer vara där är du medlem <haschtag> <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.00662899 0.2483363  0.74503472]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Jag älskar Ronaldinho   <HASCHTAG>  <HASCHTAG>
#
# Preprocessed tweet:
#  jag älskar ronaldinho <haschtag>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.05990752 0.20623864 0.73385383]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Repris från gårdagen ska nu bli intressant att se
#
# Preprocessed tweet:
#  repris från gårdagen ska nu bli intressant att se
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.14408901 0.20513174 0.65077925]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Kör bara kör!
#
# Preprocessed tweet:
#  <id> kör bara kör
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.04054469 0.40128596 0.55816935]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Herregud älskar Coutinho Vilken frispark
#
# Preprocessed tweet:
#  herregud älskar coutinho vilken frispark
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.1193962  0.05653551 0.82406828]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Tjoho! Nu fick jag hela kommunfullmäktige med mig och friidrottsarenan är tillbaka i budgeten.
#
# Preprocessed tweet:
#  tjoho nu fick jag hela kommunfullmäktige med mig och friidrottsarenan är tillbaka i budgeten
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.16252543 0.37557764 0.46189693]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
#  <ID> kul att man får reda på att du är i stan jag gillar läckerbiten, ligger precis vid skanstull. Deras plankstek
#
# Preprocessed tweet:
#  <id> kul att man får reda på att du är i stan jag gillar läckerbiten ligger precis vid skanstull deras plankstek
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.08659424 0.15650296 0.7569028 ]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> yass!!! världens finaste och bästa par
#
# Preprocessed tweet:
#  <id> yass världens finaste och bästa par
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.05400985 0.15189476 0.79409539]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Den senaste nya medlem ville gå med för att få hemförsäkring. Efter  information om även olycksfallsförsäkring så blev det ännu bättre. Ny nöjd medlem till @FacketKommunal kund till @Folksam
#
# Preprocessed tweet:
#  den senaste nya medlem ville gå med för att få hemförsäkring efter information om även olycksfallsförsäkring så blev det ännu bättre ny nöjd medlem till <id> kund till <id>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.02968807 0.33254878 0.63776315]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Vinst med 72 är godkänt Kul att Nyllet fick bra utdelning  <HASCHTAG>
#
# Preprocessed tweet:
#  vinst med 72 är godkänt kul att nyllet fick bra utdelning <haschtag>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.04108644 0.12249404 0.83641952]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Seminarieplanering! Kom och inspireras till framtidens attraktiva städer!  @SkandiaSE @RahelBelatchew @petterstordalen #stadsbyggnad #almedalen2018 https://t.co/PPPCWvFgjF
#
# Preprocessed tweet:
#  seminarieplanering kom och inspireras till framtidens attraktiva städer <id> <haschtag> <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.11991368 0.62496076 0.25512555]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Hade ju varit sjyst om vi fått till en smash & grab Vi är defensivt stabila idag som vanligt
#
# Preprocessed tweet:
#  <id> hade ju varit sjyst om vi fått till en smash grab vi är defensivt stabila idag som vanligt
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.12916761 0.28414107 0.58669132]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Eller hur Viljan finns ju där Det är små detaljer som avgör
#
# Preprocessed tweet:
#  <id> eller hur viljan finns ju där det är små detaljer som avgör
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.13948324 0.7702856  0.09023116]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Idag vill jag önska alla mina vänner en God Jul Ta hand om varandra och ät gott för det ska jag göra  blir det  <URL>
#
# Preprocessed tweet:
#  idag vill jag önska alla mina vänner en god jul ta hand om varandra och ät gott för det ska jag göra blir det <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.0115893  0.15435656 0.83405414]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Det här är bra ! <URL>
#
# Preprocessed tweet:
#  det här är bra <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.15552294 0.22418272 0.62029434]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID>  <ID>  <ID>  <ID> Tack själv Våra elever gjorde jobbet
#
# Preprocessed tweet:
#  <id> tack själv våra elever gjorde jobbet
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.07480847 0.24984285 0.67534868]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Gävle som spelplats bidrog i allra högsta grad
#
# Preprocessed tweet:
#  <id> gävle som spelplats bidrog i allra högsta grad
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.2062577 0.6097001 0.1840422]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Det här tänker jag följa den här veckan. <URL>
#
# Preprocessed tweet:
#  det här tänker jag följa den här veckan <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.02494004 0.45548849 0.51957147]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
#  Engvall tre mål idag, redan legend i djurgårdslägret. Lätt det är att bli det i den föreningen.
#
# Preprocessed tweet:
#  engvall tre mål idag redan legend i djurgårdslägret lätt det är att bli det i den föreningen
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.14000563 0.6652303  0.19476407]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Vilken fantastiskt god middag  <URL>  <URL>
#
# Preprocessed tweet:
#  vilken fantastiskt god middag <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.04675808 0.10840091 0.84484101]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
#  <ID> Men fortfarande exalterad, skall sägas
#
# Preprocessed tweet:
#  <id> men fortfarande exalterad skall sägas
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.25250577 0.46221687 0.28527736]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Jag gillade en video på <ID> <URL> Glee The final curtain interview (FULL)
#
# Preprocessed tweet:
#  jag gillade en video på <id> <url> glee the final curtain interview full
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.07133182 0.41668008 0.5119881 ]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Vilka fantastiska ungdomar vi har på väg upp framtiden ser ljus ut för Svensk Motocross  <URL>
#
# Preprocessed tweet:
#  vilka fantastiska ungdomar vi har på väg upp framtiden ser ljus ut för svensk motocross <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.09178882 0.16781354 0.74039764]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Albumet kommer va så bra
#
# Preprocessed tweet:
#  <id> albumet kommer va så bra
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.10410942 0.23327367 0.66261691]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Satte precis upp en lapp på min toa Är så rolig  <URL>
#
# Preprocessed tweet:
#  satte precis upp en lapp på min toa är så rolig <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.10962514 0.13461274 0.75576212]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID>  <ID>  <ID> Finns många bra anledningar att bjuda in mig på BBL4 Tips
#
# Preprocessed tweet:
#  <id> finns många bra anledningar att bjuda in mig på bbl4 tips
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.07905234 0.40688522 0.51406244]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Mkt bra besked från Fridolin: Regeringen vill återinföra obligatorisk prao för högstadieelever <URL>
#
# Preprocessed tweet:
#  mkt bra besked från fridolin regeringen vill återinföra obligatorisk prao för högstadieelever <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.37861798 0.23501777 0.38636425]
#
# Prediction: 	 -1
# label 		 1
#
# -------------------------
#
# Original tweet:
# @KonigLouise , hållbarhetschef @CoopSverige: tänk på hur Sverige utvecklats på 100 år. Med det perspektivet förstår man bätte vilken skillnad @weeffect kan göra i ett annat land för jämställdhet och fattigdom @riksbyggen @SveKoop @FolksamMedia @hsbisverige @LRFSverige
#
# Preprocessed tweet:
#  <id> hållbarhetschef <id> tänk på hur sverige utvecklats på 100 år med det perspektivet förstår man bätte vilken skillnad <id> kan göra i ett annat land för jämställdhet och fattigdom <id>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.36801476 0.40073045 0.23125478]
#
# Prediction: 	 -1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Gillade hur som helst hur du lyckades formulera det
#
# Preprocessed tweet:
#  <id> gillade hur som helst hur du lyckades formulera det
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.30818923 0.267259   0.42455177]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Inser först nu att  <HASCHTAG> spelar sin sista grundseriematch på en  måndag Magiskt programupplägg av  <HASCHTAG>
#
# Preprocessed tweet:
#  inser först nu att <haschtag> spelar sin sista grundseriematch på en måndag magiskt programupplägg av <haschtag>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.32697196 0.26764639 0.40538165]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Rena rama rånet ju! 60kr som hittat!
#
# Preprocessed tweet:
#  <id> rena rama rånet ju 60kr som hittat
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.36586509 0.46254836 0.17158655]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Visst var det Tusen och en natt. Och det svarade <ID> supersnabbt. Grattis.
#
# Preprocessed tweet:
#  visst var det tusen och en natt och det svarade <id> supersnabbt grattis
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.20531735 0.08837437 0.70630827]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Att ljuset gör en så lycklig
#
# Preprocessed tweet:
#  att ljuset gör en så lycklig
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.13320734 0.22564503 0.64114763]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Välkommen idag på Öppet Hus 5 oktober kl 13001500  <HASCHTAG>  <HASCHTAG>  <HASCHTAG>  <HASCHTAG>  <HASCHTAG> <URL>
#
# Preprocessed tweet:
#  välkommen idag på öppet hus 5 oktober kl 13001500 <haschtag> <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.07213557 0.23689865 0.69096578]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Den som väntar på nåt gott
#
# Preprocessed tweet:
#  <id> den som väntar på nåt gott
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.0374053  0.18209152 0.78050319]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Världens trevligaste svåger rockar på och syrran är också med! <URL> via <ID>
#
# Preprocessed tweet:
#  världens trevligaste svåger rockar på och syrran är också med <url> via <id>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.42743048 0.44788188 0.12468764]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# @MattiasMunter @SkandiaSE Ja, ser fram emot att se förslaget utvecklat i detalj. Pensionssystemet står ju inför stora utmaningar och trots detta lyser reformer till stor del med sin frånvaro.
#
# Preprocessed tweet:
#  <id> ja ser fram emot att se förslaget utvecklat i detalj pensionssystemet står ju inför stora utmaningar och trots detta lyser reformer till stor del med sin frånvaro
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.08036092 0.13068595 0.78895313]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Hoppas du har rätt
#
# Preprocessed tweet:
#  <id> hoppas du har rätt
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.18506289 0.38633857 0.42859855]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# @jensfolksam @FolksamMedia Såg hjärtat på väg hem från bio ikväll! Fint!
#
# Preprocessed tweet:
#  <id> såg hjärtat på väg hem från bio ikväll fint
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.03093299 0.21156116 0.75750585]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Vilken match Linus
#
# Preprocessed tweet:
#  <id> vilken match linus
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.16314057 0.3116777  0.52518173]
#
# Prediction: 	 1
# label 		 1
# -------------------------
#
# Original tweet:
# Tittut gött folk  <URL>
#
# Preprocessed tweet:
#  tittut gött folk <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.13637061 0.40105006 0.46257933]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Jag fick äran att gå ut på Sjövallen i Åsljunga Åshöjden med Björn Nordqvist i lördags En sån upplevelse  <URL>
#
# Preprocessed tweet:
#  jag fick äran att gå ut på sjövallen i åsljunga åshöjden med björn nordqvist i lördags en sån upplevelse <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.20840988 0.46182119 0.32976893]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Vi ses där   <ID> är en av partners till galan Håller tummarna att ni tar hem det
#
# Preprocessed tweet:
#  <id> vi ses där <id> är en av partners till galan håller tummarna att ni tar hem det
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.04422839 0.30211107 0.65366054]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# @ThomasTAndersso Hej Thomas och vad härligt att du gillade Folksams julhälsning med hjärtat som syns på vårt huvudkontor. Önskar dig en fortsatt fin dag/Tove #Folksam
#
# Preprocessed tweet:
#  <id> hej thomas och vad härligt att du gillade folksams julhälsning med hjärtat som syns på vårt huvudkontor önskar dig en fortsatt fin dag tove <haschtag>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.00806979 0.14765218 0.84427804]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Pricksäkert om Stampens uppgång och fall   <URL>
#
# Preprocessed tweet:
#  pricksäkert om stampens uppgång och fall <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.16400515 0.68924583 0.14674902]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Kristianstads sändning igår bland det bästa jag sett Bra växling mellan kameror och snyggt bildsnitt Hjälmkamera  <URL>
#
# Preprocessed tweet:
#  kristianstads sändning igår bland det bästa jag sett bra växling mellan kameror och snyggt bildsnitt hjälmkamera <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.01847492 0.07623656 0.90528852]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Bra förslag. Kram
#
# Preprocessed tweet:
#  <id> bra förslag kram
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.07860069 0.23207457 0.68932474]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Acosense välkomnar ny medarbetare Vi på Acosense är glada att få välkomna Robin Deniz som ny medarbetare Robin  <URL>
#
# Preprocessed tweet:
#  acosense välkomnar ny medarbetare vi på acosense är glada att få välkomna robin deniz som ny medarbetare robin <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.05088072 0.31509699 0.63402229]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Grattis till er! :-)
#
# Preprocessed tweet:
#  <id> grattis till er
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.17361712 0.14971247 0.67667042]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Tråkigt att höra Åsa Du är varmt välkommen tillbaka om det blir aktuellt
#
# Preprocessed tweet:
#  <id> tråkigt att höra åsa du är varmt välkommen tillbaka om det blir aktuellt
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.19203249 0.14874401 0.6592235 ]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Wow Är så impad av  <ID> Så viktig verksamhet som har potential att göra så stor skillnad
#
# Preprocessed tweet:
#  wow är så impad av <id> så viktig verksamhet som har potential att göra så stor skillnad
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.07424154 0.15299031 0.77276814]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# åhhhh klycshigaste breaket och höjning direkt på det <333
#
# Preprocessed tweet:
#  åhh klycshigaste breaket och höjning direkt på det <33
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.35832076 0.45381906 0.18786018]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Grattis  Så fin hästis du fått
#
# Preprocessed tweet:
#  <id> grattis så fin hästis du fått
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.04046327 0.07956735 0.87996939]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Viktigt perspektiv. Att så många kommer sent ut i arbete sänker pensionerna. På onsdag medverkar vår pensionsekonom @MattiasMunter i @svenaringsliv seminarium. #svpol #pension80 https://t.co/YYtVWGh4Gb
#
# Preprocessed tweet:
#  viktigt perspektiv att så många kommer sent ut i arbete sänker pensionerna på onsdag medverkar vår pensionsekonom <id> i <id> seminarium <haschtag> <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.07147822 0.76167564 0.16684614]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Använd  <URL> så ger de oss 15 var i present  <URL>
#
# Preprocessed tweet:
#  använd <url> så ger de oss 15 var i present <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.33135717 0.54724515 0.12139768]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# KARLSSON: Det kändes så värdigt att han fick lyfta pokalen först av alla <URL> <HASCHTAG> <URL>
#
# Preprocessed tweet:
#  karlsson det kändes så värdigt att han fick lyfta pokalen först av alla <url> <haschtag> <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.10945336 0.23714912 0.65339753]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Hänger på <HASCHTAG> idag. Lyssnar på intressant forskningsprojekt. ☘️ <URL>
#
# Preprocessed tweet:
#  hänger på <haschtag> idag lyssnar på intressant forskningsprojekt <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.18812041 0.29860687 0.51327272]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Bra låt ändå <URL>
#
# Preprocessed tweet:
#  bra låt ändå <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.16336395 0.1938396  0.64279645]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Vilken fin bild Tack för det fina betyget  Susanna
#
# Preprocessed tweet:
#  <id> vilken fin bild tack för det fina betyget susanna
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.01945215 0.08356286 0.89698499]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Här kan ni läsa dagens sanning  <HASCHTAG>  <URL>
#
# Preprocessed tweet:
#  här kan ni läsa dagens sanning <haschtag> <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.24855568 0.44034967 0.31109465]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# @SkandiaSE Tackar allra ödmjukast för det......
#
# Preprocessed tweet:
#  <id> tackar allra ödmjukast för det
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.0536185 0.3181387 0.6282428]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# WOW TÄNK ER VILKEN HUMANITÄR STORMAKT SVERIGE KOMMER ATT VARA MED GENIET SOM FINANSMINISTER I 21 ÅR Att  <URL>
#
# Preprocessed tweet:
#  wow tänk er vilken humanitär stormakt sverige kommer att vara med geniet som finansminister i 21 år att <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.15893104 0.42581355 0.4152554 ]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Nu börjar vi bygga hyllor i nya delen av vår lokal. Äntligen lite mer utrymme!
#
# Preprocessed tweet:
#  nu börjar vi bygga hyllor i nya delen av vår lokal äntligen lite mer utrymme
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.12497828 0.13879414 0.73622759]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Detta är den finaste och sorgligaste bilden jag har sett Kärleken min fina mormor har för hennes första kärlek  <URL>
#
# Preprocessed tweet:
#  detta är den finaste och sorgligaste bilden jag har sett kärleken min fina mormor har för hennes första kärlek <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.01546597 0.25457589 0.72995814]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Pråligt men fint  <URL>
#
# Preprocessed tweet:
#  pråligt men fint <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.08282143 0.26706513 0.65011343]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Tack Blev inte sämre när maken kom m äppelpaj o kaffe
#
# Preprocessed tweet:
#  <id> tack blev inte sämre när maken kom m äppelpaj o kaffe
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.42741378 0.14341077 0.42917546]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Ett steg mot lagstadgad lika föräldraförsäkring och samtyckeslag Bra Sverige
#
# Preprocessed tweet:
#  ett steg mot lagstadgad lika föräldraförsäkring och samtyckeslag bra sverige
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.12226397 0.40294673 0.4747893 ]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Röris steg ju i mina ögon när han kom med en sån här på fredagseftermiddagen  <HASCHTAG>  <URL>
#
# Preprocessed tweet:
#  röris steg ju i mina ögon när han kom med en sån här på fredagseftermiddagen <haschtag> <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.13519231 0.64015573 0.22465196]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Ser väldigt bra ut
#
# Preprocessed tweet:
#  <id> ser väldigt bra ut
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.14661544 0.17754548 0.67583908]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Happy Valentines alla mina fina följare ❤ Glöm aldrig att ni är tillräckliga precis som ni är ❤❤❤❤
#
# Preprocessed tweet:
#  happy valentines alla mina fina följare glöm aldrig att ni är tillräckliga precis som ni är
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.28189334 0.29828763 0.41981903]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Det tycker jag verkligen! :)
#
# Preprocessed tweet:
#  <id> det tycker jag verkligen
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.22044228 0.34481978 0.43473794]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> deal. Blir utmärkt
#
# Preprocessed tweet:
#  <id> deal blir utmärkt
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.35317462 0.27033093 0.37649445]
#
# Prediction: 	 -1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Tack  Hade dock blivit förvånad om det gått bra i drömmen för det brukar det inte göra
#
# Preprocessed tweet:
#  <id> tack hade dock blivit förvånad om det gått bra i drömmen för det brukar det inte göra
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.22640096 0.27384662 0.49975242]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Crowdfunda ut andelar nu Jag är på
#
# Preprocessed tweet:
#  <id> crowdfunda ut andelar nu jag är på
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.25531891 0.48548031 0.25920078]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Finfin illustration Olof o Lena Landström
#
# Preprocessed tweet:
#  finfin illustration olof o lena landström
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.27159756 0.49871997 0.22968247]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# @Folksam Hej, hur förmedlar jag till er brister i tillgänglighet (synbarhet) när jag anmäler skada på webben? Vill delge mig er mina synpunkter. Må Gott!
#
# Preprocessed tweet:
#  <id> hej hur förmedlar jag till er brister i tillgänglighet synbarhet när jag anmäler skada på webben vill delge mig er mina synpunkter må gott
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.1090235  0.53023531 0.36074119]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> God jul Kristoffer har inte skickat något men du har glömt mej också Post Nord kan jag bara säga gott om så använd gärna dem
#
# Preprocessed tweet:
#  <id> god jul kristoffer har inte skickat något men du har glömt mej också post nord kan jag bara säga gott om så använd gärna dem
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.02547615 0.20560198 0.76892188]
#
# Prediction: 	 1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Jag håller helt med dig
#
# Preprocessed tweet:
#  <id> jag håller helt med dig
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.12082574 0.26317237 0.61600189]
#
# Prediction: 	 1
# label 		 1
#
# ...
# [0.45495725 0.52353713 0.02150562]
#
# Prediction: 	 -1
# label 		 -1
#
# -------------------------
#
# Original tweet:
# <ID> Exakt Och super man var och varannan dag är man inte ett dugg bättre än dom som tar droger heller oavse  <URL>
#
# Preprocessed tweet:
#  <id> exakt och super man var och varannan dag är man inte ett dugg bättre än dom som tar droger heller oavse <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.09668071 0.48455509 0.41876419]
#
# Prediction: 	 0
# label 		 -1
#
# -------------------------
#
# Original tweet:
# <ID> Om jag varit med ett parti som demonstrerar samtidigt som apologeter till Venezuela och Nordkorea så  <URL>
#
# Preprocessed tweet:
#  <id> om jag varit med ett parti som demonstrerar samtidigt som apologeter till venezuela och nordkorea så <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.07016841 0.84846145 0.08137013]
#
# Prediction: 	 0
# label 		 -1
#
# -------------------------
#
# Original tweet:
#  Rögle har ingen målvakt, men Sveriges fulaste dräkter
#
# Preprocessed tweet:
#  rögle har ingen målvakt men sveriges fulaste dräkter
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.28313328 0.6727377  0.04412903]
#
# Prediction: 	 0
# label 		 -1
#
# -------------------------
#
# Original tweet:
# <ID>  <ID> Knappast där problemet sitter Hade NMR gastat samma skit så hade det manifesterats Nu är  <URL>
#
# Preprocessed tweet:
#  <id> knappast där problemet sitter hade nmr gastat samma skit så hade det manifesterats nu är <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.7883574  0.16398561 0.04765699]
#
# Prediction: 	 -1
# label 		 -1
#
# -------------------------
#
# Original tweet:
# @trygghansa @Folksam Prob anmäla en vattenskada på ett hus som ägs av ett dödsbo så jag måste prata med någon. Hur kan det vara så att jag ringde 15 - 20 gånger i fredags och 7 gånger idag och svar "vi har många som ringer och kan inte ta emot ditt samtal, ring senare"??? VERKLIGEN usel service!
#
# Preprocessed tweet:
#  <id> prob anmäla en vattenskada på ett hus som ägs av ett dödsbo så jag måste prata med någon hur kan det vara så att jag ringde 15 20 gånger i fredags och 7 gånger idag och svar vi har många som ringer och kan inte ta emot ditt samtal ring senare verkligen usel service
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.44778618 0.54977112 0.0024427 ]
#
# Prediction: 	 0
# label 		 -1
#
# -------------------------
#
# Original tweet:
# Det här är för dåligt! Vad väntar ni på tröttmössor? Mot Europa! <URL>
#
# Preprocessed tweet:
#  det här är för dåligt vad väntar ni på tröttmössor mot europa <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.7532487  0.15570834 0.09104296]
#
# Prediction: 	 -1
# label 		 -1
#
# -------------------------
#
# Original tweet:
# Kylan inne på kontoret kanske är värst men jag har ändå saknat att få börja jobba igen
#
# Preprocessed tweet:
#  kylan inne på kontoret kanske är värst men jag har ändå saknat att få börja jobba igen
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.47537917 0.28913993 0.2354809 ]
#
# Prediction: 	 -1
# label 		 -1
#
# -------------------------
#
# Original tweet:
# @palace @SkanskaSverige @KPA_pension @Folksam Verkligen. Ett bonnefix hade vilken byrörpulare som helst kunnat fixa i väntan på reservdelar. Knappast ngt Atomdrivet som kräver specialkompetens, eller hur @BylundFrank ?
#
# Preprocessed tweet:
#  <id> verkligen ett bonnefix hade vilken byrörpulare som helst kunnat fixa i väntan på reservdelar knappast ngt atomdrivet som kräver specialkompetens eller hur <id>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.56295419 0.35297753 0.08406828]
#
# Prediction: 	 -1
# label 		 -1
#
# -------------------------
#
# Original tweet:
# @RJaako @BWFCMansWi @SkandiaSE Föredömligt? Nej, FÖRDÖMLIGT menar vi!
#
# Som 30-årig man utan familj, utan skulder och utan intresse av att nyttja min överkapacitet för att gagna det här vedervärdiga landet sedan säkert halva den åldern kan jag bara säga...
#
# "Men oj. Så synd. Nu ska jag göra middag, så hejdå."
#
# Preprocessed tweet:
#  <id> föredömligt nej fördömligt menar vi som 30 årig man utan familj utan skulder och utan intresse av att nyttja min överkapacitet för att gagna det här vedervärdiga landet sedan säkert halva den åldern kan jag bara säga men oj så synd nu ska jag göra middag så hejdå
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.67499603 0.30480979 0.02019418]
#
# Prediction: 	 -1
# label 		 -1
#
# -------------------------
#
# Original tweet:
#  Vad är det med Timrå IK i dag? Otroligt många individuella misstag, många är alldeles för stillastående och inget samarbete över huvudtaget.
#
# Preprocessed tweet:
#  vad är det med timrå ik i dag otroligt många individuella misstag många är alldeles för stillastående och inget samarbete över huvudtaget
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.31095759 0.67011054 0.01893187]
#
# Prediction: 	 0
# label 		 -1
#
# -------------------------
#
# Original tweet:
# Patientsäkerheten är ju inte tipptopp om det är så heller
#
# Preprocessed tweet:
#  patientsäkerheten är ju inte tipptopp om det är så heller
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.44924987 0.44884688 0.10190325]
#
# Prediction: 	 -1
# label 		 -1
#
# -------------------------
#
# Original tweet:
# @Mariela79377749 @arvidpu @SkandiaSE För de flesta landstingen har utbetalningarna redan börjat minska. Detta är ren marknadsföring från @SkandiaSE
#
# Preprocessed tweet:
#  <id> för de flesta landstingen har utbetalningarna redan börjat minska detta är ren marknadsföring från <id>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.18342187 0.43725155 0.37932658]
#
# Prediction: 	 1
# label 		 -1
#
# -------------------------
#
# Original tweet:
# SLUTAAAAAA IFRÅGESÄTT KVINNOR NÄR DEM BERÄTTAR ATT DE BLIVIT VÅLDTAGNA!!!!!!! TRO PÅ DEM!!!! VAAAAAARFÖR SKULLE DEM LJUGA
#
# Preprocessed tweet:
#  slutaa ifrågesätt kvinnor när dem berättar att de blivit våldtagna tro på dem vaarför skulle dem ljuga
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.44497158 0.43824369 0.11678473]
#
# Prediction: 	 -1
# label 		 -1
#
# -------------------------
#
# Original tweet:
# Han är en sån idiot. Nedsättande kommentarer. Förminskar ens arbete när man slitit. Ändrar specifikationer hit och dit.
#
# Preprocessed tweet:
#  han är en sån idiot nedsättande kommentarer förminskar ens arbete när man slitit ändrar specifikationer hit och dit
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.68803149 0.27314443 0.03882408]
#
# Prediction: 	 -1
# label 		 -1
#
# -------------------------
#
# Original tweet:
# Kalmar FF Så mycket frågetecken
#
# Preprocessed tweet:
#  kalmar ff så mycket frågetecken
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.33096305 0.50746018 0.16157677]
#
# Prediction: 	 0
# label 		 -1
#
# -------------------------
#
# Original tweet:
# <ID> Nej nu har du missuppfattat Det är ju vi som är korkade som ens försöker  <ID>  <ID>  <ID>
#
# Preprocessed tweet:
#  <id> nej nu har du missuppfattat det är ju vi som är korkade som ens försöker <id>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.65993961 0.28606902 0.05399137]
#
# Prediction: 	 -1
# label 		 -1
#
# -------------------------
#
# Original tweet:
# <ID> Vem fan gillar tikitaka Målbild Terry Butcher
#
# Preprocessed tweet:
#  <id> vem fan gillar tikitaka målbild terry butcher
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.4869407  0.27313828 0.23992102]
#
# Prediction: 	 -1
# label 		 -1
#
# -------------------------
#
# Original tweet:
# PM klagör nu 0900 att tidigare rapporterat insidersälj är en flytt
#
# Preprocessed tweet:
#  pm klagör nu 0900 att tidigare rapporterat insidersälj är en flytt
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.32685761 0.30699955 0.36614284]
#
# Prediction: 	 1
# label 		 -1
#
# -------------------------
#
# Original tweet:
#  Va? En nazihyllande rasist verksam i antirasistiska Sverigedemokraterna av alla partier? Nä, dra mig baklänges. <URL>
#
# Preprocessed tweet:
#  va en nazihyllande rasist verksam i antirasistiska sverigedemokraterna av alla partier nä dra mig baklänges <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.43754333 0.37766377 0.1847929 ]
#
# Prediction: 	 -1
# label 		 -1
#
# -------------------------
#
# Original tweet:
# Linnér hit och dit. Varför står hela laget på hälarna i eget straffområde från paus till deras kvittering? Såg ju lika illa ut mot Kalmar.
#
# Preprocessed tweet:
#  linn r hit och dit varför står hela laget på hälarna i eget straffområde från paus till deras kvittering såg ju lika illa ut mot kalmar
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.12543232 0.8490569  0.02551078]
#
# Prediction: 	 0
# label 		 -1
#
# -------------------------
#
# Original tweet:
# blir så jävla trött på människor...
#
# Preprocessed tweet:
#  blir så jävla trött på människor
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.81679183 0.09776128 0.0854469 ]
#
# Prediction: 	 -1
# label 		 -1
#
# -------------------------
#
# Original tweet:
# <ID>  <ID> Tror tyvärr inte dom kommer sakna dig PGA att de tjänade noll kronor på att ha dig som kund
#
# Preprocessed tweet:
#  <id> tror tyvärr inte dom kommer sakna dig pga att de tjänade noll kronor på att ha dig som kund
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.87856861 0.0399472  0.0814842 ]
#
# Prediction: 	 -1
# label 		 -1
#
# -------------------------
#
# Original tweet:
#  <ID> Blir förbannad bara jag läser frågan, den dagen läkarvetenskapen nått så långt att vi verkligen LAGAR… <URL>
#
# Preprocessed tweet:
#  <id> blir förbannad bara jag läser frågan den dagen läkarvetenskapen nått så långt att vi verkligen lagar <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.56406611 0.16706193 0.26887196]
#
# Prediction: 	 -1
# label 		 -1
#
# -------------------------
#
# Original tweet:
# Tycker det är bull om Johan Hammar hamnar i Häcken men bättre än hif eller ifkg såklart.
#
# Preprocessed tweet:
#  tycker det är bull om johan hammar hamnar i häcken men bättre än hif eller ifkg såklart
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.25744313 0.41661429 0.32594258]
#
# Prediction: 	 0
# label 		 -1
#
# -------------------------
#
# Original tweet:
#  <ID> Bittra onödiga poängtapp där... O andra sidan skulle LFC avgjort redan i första, på de chanser de hade… <URL>
#
# Preprocessed tweet:
#  <id> bittra onödiga poängtapp där o andra sidan skulle lfc avgjort redan i första på de chanser de hade <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.13792681 0.63576831 0.22630488]
#
# Prediction: 	 0
# label 		 -1
#
# -------------------------
#
# Original tweet:
# Snöflingor förhindrade fascister från att mötas  <URL>
#
# Preprocessed tweet:
#  snöflingor förhindrade fascister från att mötas <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.20965179 0.5824949  0.20785331]
#
# Prediction: 	 0
# label 		 -1
#
# -------------------------
#
# Original tweet:
# Regeringen och @vansterpartiet har tillsammans drivit igenom förmånsbeskattning av sjukvårdsförsäkringar. Och alliansen har inte röstat ner det trots att de är emot! Leder till längre vårdköer! #svpol https://t.co/a2Hq1g16og
#
# Preprocessed tweet:
#  regeringen och <id> har tillsammans drivit igenom förmånsbeskattning av sjukvårdsförsäkringar och alliansen har inte röstat ner det trots att de är emot leder till längre vårdköer <haschtag> <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.58651119 0.10695372 0.30653509]
#
# Prediction: 	 -1
# label 		 -1
#
# -------------------------
#
# Original tweet:
# Hemmasittares mamma hotas med vite  Skolvärlden  <URL>
#
# Preprocessed tweet:
#  hemmasittares mamma hotas med vite skolvärlden <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.12614506 0.68144372 0.19241122]
#
# Prediction: 	 0
# label 		 -1
#
# -------------------------
#
# Original tweet:
# <ID> Nej pga islamisering
#
# Preprocessed tweet:
#  <id> nej pga islamisering
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.50299836 0.42713981 0.06986183]
#
# Prediction: 	 -1
# label 		 -1
#
# -------------------------
#
# Original tweet:
# Är så sjukt trött på att jag är trött hela tiden förutom när jag ska sova Tror min kropp vill leva i en annan tidszon typ
#
# Preprocessed tweet:
#  är så sjukt trött på att jag är trött hela tiden förutom när jag ska sova tror min kropp vill leva i en annan tidszon typ
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.87320824 0.11205307 0.01473868]
#
# Prediction: 	 -1
# label 		 -1
#
# -------------------------
#
# Original tweet:
# <ID>  <ID>  <ID> Som vanligt är det alltid nån annan än sv antirasistiska vänsterfeminister som ska föra feministiska
#
# Preprocessed tweet:
#  <id> som vanligt är det alltid nån annan än sv antirasistiska vänsterfeminister som ska föra feministiska
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.19093911 0.72301559 0.0860453 ]
#
# Prediction: 	 0
# label 		 -1
#
# -------------------------
#
# Original tweet:
# Hur länge ska klassförrädarna få vara kvar och leda S??? <URL> <HASCHTAG> Järva <HASCHTAG>
#
# Preprocessed tweet:
#  hur länge ska klassförrädarna få vara kvar och leda s <url> <haschtag> järva <haschtag>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.07772995 0.554342   0.36792805]
#
# Prediction: 	 0
# label 		 -1
#
# -------------------------
#
# Original tweet:
# <ID> Ett ankare Den största orsaken varför inte de andra partierna vill tala eller samarbeta med SD Fråga dem får du se
#
# Preprocessed tweet:
#  <id> ett ankare den största orsaken varför inte de andra partierna vill tala eller samarbeta med sd fråga dem får du se
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.77278053 0.20829694 0.01892253]
#
# Prediction: 	 -1
# label 		 -1
#
# -------------------------
#
# Original tweet:
# 69 Haha du fattar inte en friendzone fett synd det blir stelt
#
# Preprocessed tweet:
#  69 haha du fattar inte en friendzone fett synd det blir stelt
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.44586481 0.48663506 0.06750014]
#
# Prediction: 	 0
# label 		 -1
#
# -------------------------
#
# Original tweet:
# Nej Josefin Utas så vill vi inte ha det! Eller så borde vi inte vilja ha det alls utan i stället motarbeta så... <URL>
#
# Preprocessed tweet:
#  nej josefin utas så vill vi inte ha det eller så borde vi inte vilja ha det alls utan i stället motarbeta så <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.41399396 0.53003705 0.05596899]
#
# Prediction: 	 0
# label 		 -1
#
# -------------------------
#
# Original tweet:
# Det här är den konstigaste artikeln jag har läst på länge Kan NÅGON deschiffrera  <URL>
#
# Preprocessed tweet:
#  det här är den konstigaste artikeln jag har läst på länge kan någon deschiffrera <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.3521317  0.48325395 0.16461436]
#
# Prediction: 	 0
# label 		 -1
#
# -------------------------
#
# Original tweet:
#  Så mycket pengar kräver försvaret # Ska vi ha ett försvar värt namnet så kostar det o detta är en "piss i Nilen". <URL>
#
# Preprocessed tweet:
#  så mycket pengar kräver försvaret ska vi ha ett försvar värt namnet så kostar det o detta är en piss i nilen <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.58728444 0.17300543 0.23971013]
#
# Prediction: 	 -1
# label 		 -1
#
# -------------------------
#
# Original tweet:
# Denna borgerliga passion för sänkta löner är ofattbar. Även enkla jobb kan utföras till schyssta löner. <HASCHTAG>
#
# Preprocessed tweet:
#  denna borgerliga passion för sänkta löner är ofattbar även enkla jobb kan utföras till schyssta löner <haschtag>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.30747279 0.4383097  0.25421751]
#
# Prediction: 	 0
# label 		 -1
#
# -------------------------

# %% [markdown]
# ### Like above, but only the missclassified tweets

# %%
for index, i in enumerate(test_X):
    label = y_true[index]
    pred = y_pred[index]
    if not (label == pred):
        count += 1
        print()
        print('Original tweet:')
        print(i)
        print()
        print('Preprocessed tweet:')
        print(test_cleaned_tweets[index])
        print()
        print('Probabilities:')
        print('    neg \t neu \t   pos')
        print(y_proba[index])
        print()
        print('Prediction: \t', pred)
        print('label \t\t', label)
        print()
        print('-------------------------')
# Out:
# Original tweet:
# Drygt en vecka kvar rösta i kyrkovalet gärna på Visk till  <URL>
#
# Preprocessed tweet:
#  drygt en vecka kvar rösta i kyrkovalet gärna på visk till <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.02305637 0.58103544 0.39590819]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Synd värt ett försök
#
# Preprocessed tweet:
#  <id> synd värt ett försök
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.34851497 0.34123529 0.31024974]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Brynäs har alltså ledningen med 4-1 just nu - och de fortsätter pressa på! <HASCHTAG>
#
# Preprocessed tweet:
#  brynäs har alltså ledningen med 4 1 just nu och de fortsätter pressa på <haschtag>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.4701714  0.24561505 0.28421355]
#
# Prediction: 	 -1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Den som lägger lite tid på sin hälsa och fysik bör inte oroa sig för att jobba länge i livet.
#
# Preprocessed tweet:
#  den som lägger lite tid på sin hälsa och fysik bör inte oroa sig för att jobba länge i livet
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.34899697 0.58248699 0.06851603]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Fun fact: Vi Dabbar i dansen på insparken på mitt universitet i år x) P.S: Inte jag som var dansansvarig!!
#
# Preprocessed tweet:
#  <id> fun fact vi dabbar i dansen på insparken på mitt universitet i år x p s inte jag som var dansansvarig
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.16954714 0.7527052  0.07774766]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Kalendertävlingen gör bejublad comeback! <URL>
#
# Preprocessed tweet:
#  kalendertävlingen gör bejublad comeback <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.19279363 0.49834824 0.30885813]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# <URL> Ta ställning och visa att barn inte är till salu.
#
# Preprocessed tweet:
#  <url> ta ställning och visa att barn inte är till salu
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.67674342 0.24062842 0.08262816]
#
# Prediction: 	 -1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Det inger hopp
#
# Preprocessed tweet:
#  <id> det inger hopp
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.38117358 0.2306956  0.38813082]
#
# Prediction: 	 -1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Måste genast lokalisera närmsta blodbuss och testa känns det som
#
# Preprocessed tweet:
#  <id> måste genast lokalisera närmsta blodbuss och testa känns det som
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.38601154 0.33889924 0.27508922]
#
# Prediction: 	 -1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Jag ska på överraskningsfest ikväll Alltså festen är bara en överraskning för mig eftersom han glömt att berätta om den för mig
#
# Preprocessed tweet:
#  jag ska på överraskningsfest ikväll alltså festen är bara en överraskning för mig eftersom han glömt att berätta om den för mig
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.39639628 0.51255236 0.09105136]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Hahaha! Dansbandskanalen Jul finns ju dock nu såg jag. På tiden!
#
# Preprocessed tweet:
#  <id> hahaha dansbandskanalen jul finns ju dock nu såg jag på tiden
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.10130177 0.48833415 0.41036408]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Jo då, vi hade en kanonkväll i #Eftersnack från @skandiase trädgård i #Almedalen och i @expressentv. I morgon är vi tillbaka, 19.00-20.15. Samma plats, nya gäster. https://t.co/DmyILvVM3i
#
# Preprocessed tweet:
#  jo då vi hade en kanonkväll i <haschtag> från <id> trädgård i <haschtag> och i <id> i morgon är vi tillbaka 19 00 20 15 samma plats nya gäster <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.0349518  0.84577624 0.11927197]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Helt rätt målvaktsval av Färjestad  <ID>
#
# Preprocessed tweet:
#  helt rätt målvaktsval av färjestad <id>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.19628971 0.38505784 0.41865245]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Pantern borde få spela i SHL med den publiksiffran Flytta upp dom direkt
#
# Preprocessed tweet:
#  pantern borde få spela i shl med den publiksiffran flytta upp dom direkt
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.43850969 0.45694767 0.10454264]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Tänk att det är så roligt att titta bakom kulisserna! <ID> på Bonniers Konsthall <URL>
#
# Preprocessed tweet:
#  tänk att det är så roligt att titta bakom kulisserna <id> på bonniers konsthall <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.03817686 0.54513909 0.41668405]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Låg och snarkade Men det låter ju som en story av guds nåde
#
# Preprocessed tweet:
#  <id> låg och snarkade men det låter ju som en story av guds nåde
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.41838321 0.35105398 0.23056281]
#
# Prediction: 	 -1
# label 		 1
#
# -------------------------
#
# Original tweet:
#  Vad fantastiskt det är att jag en söndag kan beställa hundfoder, på mobilen, för leverans ända fram till dörren! <HASCHTAG>
#
# Preprocessed tweet:
#  vad fantastiskt det är att jag en söndag kan beställa hundfoder på mobilen för leverans ända fram till dörren <haschtag>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.09056207 0.48013477 0.42930316]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID>  <ID> Er nya politik med samordnare innovationskatapulter traineejobb industrikansler har ju gått så bra
#
# Preprocessed tweet:
#  <id> er nya politik med samordnare innovationskatapulter traineejobb industrikansler har ju gått så bra
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.13367758 0.51814633 0.34817609]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> ja det är vi överens om
#
# Preprocessed tweet:
#  <id> ja det är vi överens om
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.33094504 0.5105092  0.15854576]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Tack Familjen Skott i Estland för Årets påsklamm! (ping Lennart Skott)
#
# Preprocessed tweet:
#  tack familjen skott i estland för årets påsklamm ping lennart skott
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.15277666 0.46230731 0.38491603]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Hasse Borg gjorde ett par riktigt sjuka fönster i MFF
#
# Preprocessed tweet:
#  <id> hasse borg gjorde ett par riktigt sjuka fönster i mff
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.3357821  0.59257447 0.07164343]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> kan ni snälla komma och stötta
#
# Preprocessed tweet:
#  <id> kan ni snälla komma och stötta
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.37544656 0.36509781 0.25945564]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# 11 Du kan alltid räkna med mig när det kommer till att äta upp din mat Så lämna mig inte utan uppsikt inte ens när du bara ska ner till gt
#
# Preprocessed tweet:
#  11 du kan alltid räkna med mig när det kommer till att äta upp din mat så lämna mig inte utan uppsikt inte ens när du bara ska ner till gt
#
# Probabilities:
#     neg 	 neu 	   pos
# [5.15020164e-01 4.84575006e-01 4.04830578e-04]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Seminarieplanering! Kom och inspireras till framtidens attraktiva städer!  @SkandiaSE @RahelBelatchew @petterstordalen #stadsbyggnad #almedalen2018 https://t.co/PPPCWvFgjF
#
# Preprocessed tweet:
#  seminarieplanering kom och inspireras till framtidens attraktiva städer <id> <haschtag> <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.11991368 0.62496076 0.25512555]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Eller hur Viljan finns ju där Det är små detaljer som avgör
#
# Preprocessed tweet:
#  <id> eller hur viljan finns ju där det är små detaljer som avgör
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.13948324 0.7702856  0.09023116]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Gävle som spelplats bidrog i allra högsta grad
#
# Preprocessed tweet:
#  <id> gävle som spelplats bidrog i allra högsta grad
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.2062577 0.6097001 0.1840422]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
#  Engvall tre mål idag, redan legend i djurgårdslägret. Lätt det är att bli det i den föreningen.
#
# Preprocessed tweet:
#  engvall tre mål idag redan legend i djurgårdslägret lätt det är att bli det i den föreningen
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.14000563 0.6652303  0.19476407]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
#  <ID> Men fortfarande exalterad, skall sägas
#
# Preprocessed tweet:
#  <id> men fortfarande exalterad skall sägas
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.25250577 0.46221687 0.28527736]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Mkt bra besked från Fridolin: Regeringen vill återinföra obligatorisk prao för högstadieelever <URL>
#
# Preprocessed tweet:
#  mkt bra besked från fridolin regeringen vill återinföra obligatorisk prao för högstadieelever <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.37861798 0.23501777 0.38636425]
#
# Prediction: 	 -1
# label 		 1
#
# -------------------------
#
# Original tweet:
# @KonigLouise , hållbarhetschef @CoopSverige: tänk på hur Sverige utvecklats på 100 år. Med det perspektivet förstår man bätte vilken skillnad @weeffect kan göra i ett annat land för jämställdhet och fattigdom @riksbyggen @SveKoop @FolksamMedia @hsbisverige @LRFSverige
#
# Preprocessed tweet:
#  <id> hållbarhetschef <id> tänk på hur sverige utvecklats på 100 år med det perspektivet förstår man bätte vilken skillnad <id> kan göra i ett annat land för jämställdhet och fattigdom <id>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.36801476 0.40073045 0.23125478]
#
# Prediction: 	 -1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Rena rama rånet ju! 60kr som hittat!
#
# Preprocessed tweet:
#  <id> rena rama rånet ju 60kr som hittat
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.36586509 0.46254836 0.17158655]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Världens trevligaste svåger rockar på och syrran är också med! <URL> via <ID>
#
# Preprocessed tweet:
#  världens trevligaste svåger rockar på och syrran är också med <url> via <id>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.42743048 0.44788188 0.12468764]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Pricksäkert om Stampens uppgång och fall   <URL>
#
# Preprocessed tweet:
#  pricksäkert om stampens uppgång och fall <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.16400515 0.68924583 0.14674902]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# åhhhh klycshigaste breaket och höjning direkt på det <333
#
# Preprocessed tweet:
#  åhh klycshigaste breaket och höjning direkt på det <33
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.35832076 0.45381906 0.18786018]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Viktigt perspektiv. Att så många kommer sent ut i arbete sänker pensionerna. På onsdag medverkar vår pensionsekonom @MattiasMunter i @svenaringsliv seminarium. #svpol #pension80 https://t.co/YYtVWGh4Gb
#
# Preprocessed tweet:
#  viktigt perspektiv att så många kommer sent ut i arbete sänker pensionerna på onsdag medverkar vår pensionsekonom <id> i <id> seminarium <haschtag> <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.07147822 0.76167564 0.16684614]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Använd  <URL> så ger de oss 15 var i present  <URL>
#
# Preprocessed tweet:
#  använd <url> så ger de oss 15 var i present <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.33135717 0.54724515 0.12139768]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Här kan ni läsa dagens sanning  <HASCHTAG>  <URL>
#
# Preprocessed tweet:
#  här kan ni läsa dagens sanning <haschtag> <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.24855568 0.44034967 0.31109465]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Röris steg ju i mina ögon när han kom med en sån här på fredagseftermiddagen  <HASCHTAG>  <URL>
#
# Preprocessed tweet:
#  röris steg ju i mina ögon när han kom med en sån här på fredagseftermiddagen <haschtag> <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.13519231 0.64015573 0.22465196]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> deal. Blir utmärkt
#
# Preprocessed tweet:
#  <id> deal blir utmärkt
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.35317462 0.27033093 0.37649445]
#
# Prediction: 	 -1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Crowdfunda ut andelar nu Jag är på
#
# Preprocessed tweet:
#  <id> crowdfunda ut andelar nu jag är på
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.25531891 0.48548031 0.25920078]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Finfin illustration Olof o Lena Landström
#
# Preprocessed tweet:
#  finfin illustration olof o lena landström
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.27159756 0.49871997 0.22968247]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# @Folksam Hej, hur förmedlar jag till er brister i tillgänglighet (synbarhet) när jag anmäler skada på webben? Vill delge mig er mina synpunkter. Må Gott!
#
# Preprocessed tweet:
#  <id> hej hur förmedlar jag till er brister i tillgänglighet synbarhet när jag anmäler skada på webben vill delge mig er mina synpunkter må gott
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.1090235  0.53023531 0.36074119]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Världsunika Molly hittar fuskarna och Molly är försäkrad i idrottens försäkringsbolag, Folksam! 😊 #folksam #doping https://t.co/gBmcrRfOyG
#
# Preprocessed tweet:
#  världsunika molly hittar fuskarna och molly är försäkrad i idrottens försäkringsbolag folksam <haschtag> <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.14396928 0.66068491 0.19534581]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Stiligt pluspoäng för att du färgkoordinerade slipsen med näsduk och knapphål.
#
# Preprocessed tweet:
#  <id> stiligt pluspoäng för att du färgkoordinerade slipsen med näsduk och knapphål
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.18919519 0.63781891 0.1729859 ]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID>  <ID> Hahaha humor humor
#
# Preprocessed tweet:
#  <id> hahaha humor humor
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.07203482 0.57044303 0.35752214]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Nationaldagsfirande. Som en mästarstad. <URL>
#
# Preprocessed tweet:
#  nationaldagsfirande som en mästarstad <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.21545475 0.52727317 0.25727208]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# @FolksamMedia @jensfolksam @realtid Mycket insiktsfullt!
#
# Preprocessed tweet:
#  <id> mycket insiktsfullt
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.2664068  0.40498797 0.32860524]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# <HASCHTAG> blir populär igen  <URL>
#
# Preprocessed tweet:
#  <haschtag> blir populär igen <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.21924971 0.43640237 0.34434792]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# KLART IDAG Ny butik i Sävsjö  <URL>
#
# Preprocessed tweet:
#  klart idag ny butik i sävsjö <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.1102129  0.54014391 0.34964319]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Har nog inte sett så många  <ID> matcher i hela mitt 36åriga liv som jag sett denna säsong
#
# Preprocessed tweet:
#  har nog inte sett så många <id> matcher i hela mitt 36åriga liv som jag sett denna säsong
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.39178787 0.58440699 0.02380514]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# I morgon smäller det. Håll koll på <HASCHTAG> <URL>
#
# Preprocessed tweet:
#  i morgon smäller det håll koll på <haschtag> <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.19200773 0.42373428 0.38425799]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
#  <ID> jodå, hade ätit, sovit och druckit som man ska
#
# Preprocessed tweet:
#  <id> jodå hade ätit sovit och druckit som man ska
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.23871491 0.67634532 0.08493977]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# På  <ID> show Fullsatt och supermycket glasögon i publiken Sveriges mest pålästa och närsynta publik
#
# Preprocessed tweet:
#  på <id> show fullsatt och supermycket glasögon i publiken sveriges mest pålästa och närsynta publik
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.18091766 0.5406063  0.27847604]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Trots en rejäl uppgång 2016 spår banken att det är långt kvar tills pristaket är nått. <URL>
#
# Preprocessed tweet:
#  trots en rejäl uppgång 2016 spår banken att det är långt kvar tills pristaket är nått <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.27277029 0.47616155 0.25106816]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID>  <ID> Vaccin på en försvarshälsa nära dig
#
# Preprocessed tweet:
#  <id> vaccin på en försvarshälsa nära dig
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.34662237 0.45631876 0.19705887]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Följ  <ID> för lite mer äkta borgerlighet i ditt flöde Hoppas dessutom på uppdateringar från hans militära GU med start i höst
#
# Preprocessed tweet:
#  följ <id> för lite mer äkta borgerlighet i ditt flöde hoppas dessutom på uppdateringar från hans militära gu med start i höst
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.22818796 0.75589438 0.01591766]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
#  VILL HA, eller hur? <URL>
#
# Preprocessed tweet:
#  vill ha eller hur <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.21337026 0.65616029 0.13046945]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
#  Brukar aldrig skryta med prylar, men min nya kaffebryggare är fan något extra. Den som känner… <URL>
#
# Preprocessed tweet:
#  brukar aldrig skryta med prylar men min nya kaffebryggare är fan något extra den som känner <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.52759806 0.42303249 0.04936945]
#
# Prediction: 	 -1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Alltså herremingud Donovan Mitchell Galen stop and spin  <URL>
#
# Preprocessed tweet:
#  alltså herremingud donovan mitchell galen stop and spin <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.18130125 0.50927014 0.3094286 ]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# 10 grader en helt vanlig lördagVad gör runt 400 människor från  <URL>
#
# Preprocessed tweet:
#  10 grader en helt vanlig lördagvad gör runt 400 människor från <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.05504568 0.52776098 0.41719334]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# @jbarrpartarr @Seb Hej! Vi får inte lov att kommentera enskilda ärenden eller försäkringar via sociala medier, men om du skickar ditt telefonnummer eller din mejladress via ett DM till oss så kontaktar vi dig gärna för att se över ditt ärende. //Annica #Folksam
#
# Preprocessed tweet:
#  <id> hej vi får inte lov att kommentera enskilda ärenden eller försäkringar via sociala medier men om du skickar ditt telefonnummer eller din mejladress via ett dm till oss så kontaktar vi dig gärna för att se över ditt ärende annica <haschtag>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.19369598 0.58980647 0.21649755]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Verkar som folk aldrig sett lopp från USA Va lite fucking stolt över vad Åke och hans personal lyckats med Inte varje år detta händer
#
# Preprocessed tweet:
#  verkar som folk aldrig sett lopp från usa va lite fucking stolt över vad åke och hans personal lyckats med inte varje år detta händer
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.79854524 0.19534815 0.00610661]
#
# Prediction: 	 -1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Ja för tusan
#
# Preprocessed tweet:
#  <id> ja för tusan
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.20533154 0.45340705 0.34126141]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Glädjebeskedet för <ID> - stjärnan gör comeback. <HASCHTAG> <URL>
#
# Preprocessed tweet:
#  glädjebeskedet för <id> stjärnan gör comeback <haschtag> <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.21395529 0.46578507 0.32025964]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> En och en är dom däremot ljuvliga. :)
#
# Preprocessed tweet:
#  <id> en och en är dom däremot ljuvliga
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.42295721 0.381519   0.1955238 ]
#
# Prediction: 	 -1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Förre HBKaren hittar åter målet Marcus Antonsson har hittat nivån i England  <URL>  <HASCHTAG>  <HASCHTAG>  <HASCHTAG>
#
# Preprocessed tweet:
#  förre hbkaren hittar åter målet marcus antonsson har hittat nivån i england <url> <haschtag>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.06269825 0.61886585 0.3184359 ]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Det luktar nyförvärv! <URL>
#
# Preprocessed tweet:
#  det luktar nyförvärv <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.27580138 0.48980623 0.23439238]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Alla är så negativa till snön och själv så ska jag ut och åka pulka
#
# Preprocessed tweet:
#  alla är så negativa till snön och själv så ska jag ut och åka pulka
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.34433052 0.52480624 0.13086324]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Du kan komma hem till din storebror och mysa
#
# Preprocessed tweet:
#  <id> du kan komma hem till din storebror och mysa
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.15898713 0.53333466 0.30767821]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Bra utdelning för dem ändå får man säga. Det är väl bara Sabovic i den trion som inte fått testa kaptensbindeln?
#
# Preprocessed tweet:
#  <id> bra utdelning för dem ändå får man säga det är väl bara sabovic i den trion som inte fått testa kaptensbindeln
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.21845862 0.50179229 0.27974909]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Känslan när man kommer på att det finns maräncup i frysen för att glassbilen var på besök förra veckan  <HASCHTAG>
#
# Preprocessed tweet:
#  känslan när man kommer på att det finns maräncup i frysen för att glassbilen var på besök förra veckan <haschtag>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.36245686 0.55709449 0.08044865]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Stort intresse för pensioner i @SkandiaSE’s trädgård, lokalen är överfull! #almedalen #pension80 https://t.co/N2a0oOMKA2
#
# Preprocessed tweet:
#  stort intresse för pensioner i <id> trädgård lokalen är överfull <haschtag> <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.12792893 0.56013555 0.31193552]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Är i dag nöjd över investering i stolta och hållbara Stockholm #folksam https://t.co/T66YnvIT7P
#
# Preprocessed tweet:
#  är i dag nöjd över investering i stolta och hållbara stockholm <haschtag> <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.07658779 0.53707176 0.38634045]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Väntar nu spänt på första inlägget
#
# Preprocessed tweet:
#  <id> väntar nu spänt på första inlägget
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.22127483 0.43513281 0.34359236]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> aa  lite skulle vilja ha en fotbollshalsduk
#
# Preprocessed tweet:
#  <id> aa lite skulle vilja ha en fotbollshalsduk
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.13841358 0.50115392 0.3604325 ]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Frälsningsarmen insatser från Texas är nu i Florida för att hjälpa det som drabbats av orkanen  <HASCHTAG> se klippet  <URL>
#
# Preprocessed tweet:
#  frälsningsarmen insatser från texas är nu i florida för att hjälpa det som drabbats av orkanen <haschtag> se klippet <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.20845779 0.55540822 0.23613399]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID>  <ID> Jag kan säga så här att jag är väldigt glad att Spurs har Pochettino som tränare amp inte Wenger
#
# Preprocessed tweet:
#  <id> jag kan säga så här att jag är väldigt glad att spurs har pochettino som tränare inte wenger
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.07676315 0.4449764  0.47826044]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Den bubblar så förföriskt i mikron nu Snart mon amour
#
# Preprocessed tweet:
#  den bubblar så förföriskt i mikron nu snart mon amour
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.2165581  0.51709812 0.26634378]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Ren vinst med ensamkommande flyktingpojkar ju Löfven har sagt att tusentals döda försöker ta sig till Sverige  <URL>
#
# Preprocessed tweet:
#  <id> ren vinst med ensamkommande flyktingpojkar ju löfven har sagt att tusentals döda försöker ta sig till sverige <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.50444518 0.29573842 0.1998164 ]
#
# Prediction: 	 -1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Smarrig slutprodukt även på den här   <URL>
#
# Preprocessed tweet:
#  smarrig slutprodukt även på den här <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.15506909 0.45010235 0.39482856]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# @pippinuna @trygghansa Tycker synd om dig Ludvig! Du är stark!❤️
#
# Preprocessed tweet:
#  <id> tycker synd om dig ludvig du är stark
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.28574517 0.39591044 0.31834438]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# TV Yasin bakom Häckens seger  ny tabelltvåa i allsvenskan <URL>  <URL>
#
# Preprocessed tweet:
#  tv yasin bakom häckens seger ny tabelltvåa i allsvenskan <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.09524346 0.75286606 0.15189048]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# God middag blåst och horisontellt regn AKA Göteborgsväder  <URL>
#
# Preprocessed tweet:
#  god middag blåst och horisontellt regn aka göteborgsväder <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.08974288 0.55085212 0.35940501]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Bekvämt ändå att få straffen som gjorde det sjuka möjligt till skänks. Otrolig match men luktar ändå lite illa.
#
# Preprocessed tweet:
#  bekvämt ändå att få straffen som gjorde det sjuka möjligt till skänks otrolig match men luktar ändå lite illa
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.56435162 0.28388173 0.15176665]
#
# Prediction: 	 -1
# label 		 1
#
# -------------------------
#
# Original tweet:
# Matäventyr här och där - torsdag 16 februari 00:01 <URL>
#
# Preprocessed tweet:
#  matäventyr här och där torsdag 16 februari 00 01 <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.06610479 0.54425805 0.38963717]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Haha Herregud  Verkar finnas ett par liknande till
#
# Preprocessed tweet:
#  <id> haha herregud verkar finnas ett par liknande till
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.39405251 0.36439552 0.24155196]
#
# Prediction: 	 -1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID>  <ID> inte lukta usch stå högt i kurs
#
# Preprocessed tweet:
#  <id> inte lukta usch stå högt i kurs
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.36016469 0.59371898 0.04611634]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Säsong två blev den bättre för mig iaf :)
#
# Preprocessed tweet:
#  <id> säsong två blev den bättre för mig iaf
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.11071798 0.48888603 0.40039599]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Ledig dag ! Kan inte ta mig ifrån golfbanan ändå. Titta på Kajsa 18 hål som spelar Skandia Tour för att sedan... <URL>
#
# Preprocessed tweet:
#  ledig dag kan inte ta mig ifrån golfbanan ändå titta på kajsa 18 hål som spelar skandia tour för att sedan <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.14373337 0.57826673 0.2779999 ]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Som småbarnsförälder känner du säkert igen läget Passionen och envisheten Men störst av allt är lekfullheten  <URL>
#
# Preprocessed tweet:
#  som småbarnsförälder känner du säkert igen läget passionen och envisheten men störst av allt är lekfullheten <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.15759337 0.60637947 0.23602716]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Skål allihopa för att Brynäs ligger sist.
#
# Preprocessed tweet:
#  skål allihopa för att brynäs ligger sist
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.27985194 0.5050423  0.21510576]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID>  <ID>  <ID>  <ID> Det är mäktig  <HASCHTAG>
#
# Preprocessed tweet:
#  <id> det är mäktig <haschtag>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.23038706 0.49506399 0.27454895]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
#  <ID> Långsam metod: batteriladdare, snabb metod: En annan bil för starthjälp. Jag kan inget om hjälpbatterier, vet inte ens vad det är.
#
# Preprocessed tweet:
#  <id> långsam metod batteriladdare snabb metod en annan bil för starthjälp jag kan inget om hjälpbatterier vet inte ens vad det är
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.35657204 0.64179298 0.00163498]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Inger en känsla av godhet att lämna sin syrgasmask till grannen.
#
# Preprocessed tweet:
#  <id> inger en känsla av godhet att lämna sin syrgasmask till grannen
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.61624151 0.2436586  0.14009989]
#
# Prediction: 	 -1
# label 		 1
#
# -------------------------
#
# Original tweet:
# En dag för eftertanke  <URL>
#
# Preprocessed tweet:
#  en dag för eftertanke <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.23057682 0.5649242  0.20449898]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Vi leker lek o Karin får en fråga Nämn 8 professionella fotbollsspelare Och hon säger Johan Elmander Ja han är ju den man tänker på då
#
# Preprocessed tweet:
#  vi leker lek o karin får en fråga nämn 8 professionella fotbollsspelare och hon säger johan elmander ja han är ju den man tänker på då
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.13864898 0.4615166  0.39983442]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Vi har ett helt gäng skickliga producenter och låtskrivare. Lätt löst! =)
#
# Preprocessed tweet:
#  <id> vi har ett helt gäng skickliga producenter och låtskrivare lätt löst
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.31547668 0.49174147 0.19278185]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Minns en lärarkandidat i mellanstadiet som skrev namndikter till oss. Fick: Mycket mycket intelligent Yrvaken som en solstråle
#
# Preprocessed tweet:
#  minns en lärarkandidat i mellanstadiet som skrev namndikter till oss fick mycket mycket intelligent yrvaken som en solstråle
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.2379117  0.52802895 0.23405934]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
#  <ID> Av erfarenhet vet jag dessutom att väldigt många tränare, på frågorna "Hur är formen?" eller ""Hur… <URL>
#
# Preprocessed tweet:
#  <id> av erfarenhet vet jag dessutom att väldigt många tränare på frågorna hur är formen eller hur <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.04264244 0.88594524 0.07141232]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
#  <ID> Jupp, men den hade blivit en succé även om den inte fått skinande mottagande.
#
# Preprocessed tweet:
#  <id> jupp men den hade blivit en succ även om den inte fått skinande mottagande
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.23526682 0.39543368 0.3692995 ]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# Stort Värmer Ansvarstagande All heder åt Brynäs för detta arbete information och initiativuppmaning  <URL>
#
# Preprocessed tweet:
#  stort värmer ansvarstagande all heder åt brynäs för detta arbete information och initiativuppmaning <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.45178133 0.16846784 0.37975083]
#
# Prediction: 	 -1
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID> Ja det kan jag bara hålla med om
#
# Preprocessed tweet:
#  <id> ja det kan jag bara hålla med om
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.20152649 0.42595213 0.37252138]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# <ID>  <ID>  <ID> Prova Fridens liljor
#
# Preprocessed tweet:
#  <id> prova fridens liljor
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.23714993 0.4139363  0.34891377]
#
# Prediction: 	 0
# label 		 1
#
# -------------------------
#
# Original tweet:
# @BoaormRolf Hej och tack för ditt meddelande. Jag förstår att du vill ha ditt brev snabbt. Folksam skickar väldigt många brev till våra kunder per dag och i första hand går dessa B-post för att hålla nere kostnaderna. Vill du ha brev från oss snabbt, anslut till Kivra/Tove #Folksam
#
# Preprocessed tweet:
#  <id> hej och tack för ditt meddelande jag förstår att du vill ha ditt brev snabbt folksam skickar väldigt många brev till våra kunder per dag och i första hand går dessa b post för att hålla nere kostnaderna vill du ha brev från oss snabbt anslut till kivra tove <haschtag>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.13789935 0.45147631 0.41062434]
#
# Prediction: 	 1
# label 		 0
#
# -------------------------
#
# Original tweet:
# Fagervall Väldigt omtumlande självklart  <URL>
#
# Preprocessed tweet:
#  fagervall väldigt omtumlande självklart <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.11907038 0.28080548 0.60012414]
#
# Prediction: 	 1
# label 		 0
#
# -------------------------
#
# Original tweet:
# @Elake_Karsten @PontusHaag @SkandiaSE Du @PontusHaag befinner dig i fel tidsperiod och bör uppdatera dig snarast på verkligheten
#
# Preprocessed tweet:
#  <id> du <id> befinner dig i fel tidsperiod och bör uppdatera dig snarast på verkligheten
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.35205801 0.45431634 0.19362565]
#
# Prediction: 	 -1
# label 		 0
#
# -------------------------
#
# Original tweet:
# Nu släpps biobiljetterna till ”Star Wars: The Last Jedi”! <URL>
#
# Preprocessed tweet:
#  nu släpps biobiljetterna till star wars the last jedi <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.08939715 0.34583687 0.56476598]
#
# Prediction: 	 1
# label 		 0
#
# -------------------------
#
# Original tweet:
# <ID> syfte. Men ja vet ju att folk ändå inte hade gått ut å käkat så varför ens ha öppet! Då… <URL>
#
# Preprocessed tweet:
#  <id> syfte men ja vet ju att folk ändå inte hade gått ut å käkat så varför ens ha öppet då <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.75023141 0.2461563  0.00361229]
#
# Prediction: 	 -1
# label 		 0
#
# -------------------------
#
# Original tweet:
# @trygghansa Jag skulle behöva kommunicera mer er via e-post. Vilken adress ska jag använda?
#
# Preprocessed tweet:
#  <id> jag skulle behöva kommunicera mer er via e post vilken adress ska jag använda
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.33070721 0.35493683 0.31435596]
#
# Prediction: 	 1
# label 		 0
#
# -------------------------
#
# Original tweet:
# <ID>  <ID> Frågan är Mår dom dåligt eller kräver dom respekt
#
# Preprocessed tweet:
#  <id> frågan är mår dom dåligt eller kräver dom respekt
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.69602088 0.23893134 0.06504778]
#
# Prediction: 	 -1
# label 		 0
#
# -------------------------
#
# Original tweet:
# <ID> Vad tycker du borde göras mer  <ID>  <ID>  <ID>
#
# Preprocessed tweet:
#  <id> vad tycker du borde göras mer <id>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.13253063 0.30849013 0.55897924]
#
# Prediction: 	 1
# label 		 0
#
# -------------------------
#
# Original tweet:
# @SkandiaSE Börja med 6-timmars arbetsdag så är mycket vunnet.
#
# Preprocessed tweet:
#  <id> börja med 6 timmars arbetsdag så är mycket vunnet
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.54134895 0.16443296 0.29421809]
#
# Prediction: 	 -1
# label 		 0
#
# -------------------------
#
# Original tweet:
#  <ID> Jag har varit mycket i Marrakesh och tillbringat mycket tid hos matthandlarna, fantastisk… <URL>
#
# Preprocessed tweet:
#  <id> jag har varit mycket i marrakesh och tillbringat mycket tid hos matthandlarna fantastisk <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.16057763 0.33314708 0.50627529]
#
# Prediction: 	 1
# label 		 0
#
# -------------------------
#
# Original tweet:
# Bara 90-talskids kommer ihåg det här: känslan att få ett email och bli glad istället för att vägra öppna det och vilja dö
#
# Preprocessed tweet:
#  bara 90 talskids kommer ihåg det här känslan att få ett email och bli glad istället för att vägra öppna det och vilja dö
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.40245405 0.02497946 0.57256648]
#
# Prediction: 	 1
# label 		 0
#
# -------------------------
#
# Original tweet:
# <ID> Stämmer. I slutet av 80-talet. Var inte det en bra ide´?
#
# Preprocessed tweet:
#  <id> stämmer i slutet av 80 talet var inte det en bra ide
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.17653942 0.35581246 0.46764811]
#
# Prediction: 	 1
# label 		 0
#
# -------------------------
#
# Original tweet:
# <ID> Hahaha. Ingenting inspirerer meg som GT-Sara.
#
# Preprocessed tweet:
#  <id> hahaha ingenting inspirerer meg som gt sara
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.42425336 0.31929163 0.25645501]
#
# Prediction: 	 -1
# label 		 0
#
# -------------------------
#
# Original tweet:
# @Tarasus81 @BWFCMansWi @SkandiaSE Men varför skulle de vara som högst nu?
# Varför tycker du att mörka dem är att hantera utmärkt ?
#
# Preprocessed tweet:
#  <id> men varför skulle de vara som högst nu varför tycker du att mörka dem är att hantera utmärkt
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.64030733 0.22371857 0.13597409]
#
# Prediction: 	 -1
# label 		 0
#
# -------------------------
#
# Original tweet:
#  <ID> och statsministern mumsar på sin julkorv i lugn o ro, stabilt
#
# Preprocessed tweet:
#  <id> och statsministern mumsar på sin julkorv i lugn o ro stabilt
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.33560081 0.27272667 0.39167251]
#
# Prediction: 	 1
# label 		 0
#
# -------------------------
#
# Original tweet:
# <ID> O i slutändan tillägga en tyst minut för nationen Sverige.
#
# Preprocessed tweet:
#  <id> o i slutändan tillägga en tyst minut för nationen sverige
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.41023927 0.37262453 0.2171362 ]
#
# Prediction: 	 -1
# label 		 0
#
# -------------------------
#
# Original tweet:
# Många har uppmärksammat att  <HASCHTAG> tyvärr säger nej till solceller  <HASCHTAG>  <HASCHTAG>  <HASCHTAG>  <URL>
#
# Preprocessed tweet:
#  många har uppmärksammat att <haschtag> tyvärr säger nej till solceller <haschtag> <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.60920246 0.32266097 0.06813657]
#
# Prediction: 	 -1
# label 		 0
#
# -------------------------
#
# Original tweet:
# United är en liten damm som slåss om europaleague
#
# Preprocessed tweet:
#  united är en liten damm som slåss om europaleague
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.09994621 0.37828457 0.52176922]
#
# Prediction: 	 1
# label 		 0
#
# -------------------------
#
# Original tweet:
# @Fkiltorp Jag hoppas polotröjan är från Trygg hansa!
#
# Preprocessed tweet:
#  <id> jag hoppas polotröjan är från trygg hansa
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.15065637 0.38523905 0.46410458]
#
# Prediction: 	 1
# label 		 0
#
# -------------------------
#
# Original tweet:
# Jag har väntat så länge på just denna dag... <URL>
#
# Preprocessed tweet:
#  jag har väntat så länge på just denna dag <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.25936365 0.33187197 0.40876438]
#
# Prediction: 	 1
# label 		 0
#
# -------------------------
#
# Original tweet:
# @viola_maj @SkandiaSE Gillar hur du uttrycker dig att man per automatik har rätt till skattemedel med ett läkarintyg. Då hade ingen behövt arbeta och stå för någon annans ”rätt” till ersättning.
#
# Preprocessed tweet:
#  <id> gillar hur du uttrycker dig att man per automatik har rätt till skattemedel med ett läkarintyg då hade ingen behövt arbeta och stå för någon annans rätt till ersättning
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.41537171 0.13761389 0.44701441]
#
# Prediction: 	 1
# label 		 0
#
# -------------------------
#
# Original tweet:
# 18 års fängelse för muslimer som kastade kristna överbord till en säker död <URL> via <ID>
#
# Preprocessed tweet:
#  18 års fängelse för muslimer som kastade kristna överbord till en säker död <url> via <id>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.63823399 0.22507255 0.13669346]
#
# Prediction: 	 -1
# label 		 0
#
# -------------------------
#
# Original tweet:
# @olovsjolander @avanzabank @NordnetSE Gör en jämförelse av billiga indexfonder så ser du att @SkandiaSE inte hamnar lika långt ner i avgift ... (är kund hos samtliga tre)
#
# Preprocessed tweet:
#  <id> gör en jämförelse av billiga indexfonder så ser du att <id> inte hamnar lika långt ner i avgift är kund hos samtliga tre
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.66267467 0.32751825 0.00980709]
#
# Prediction: 	 -1
# label 		 0
#
# -------------------------
#
# Original tweet:
# <ID> Bra förslag men för lite.
#
# ...
#     neg 	 neu 	   pos
# [0.3140857  0.21747928 0.46843502]
#
# Prediction: 	 1
# label 		 -1
#
# -------------------------
#
# Original tweet:
# @SkandiaSE varför ska det vara så förtvivlat svårt att i egenskap av privatperson handla fonder med fokus på klimat och förnybar energi? De få fonder jag hittar ger felmeddelande att endast professionella placerare får köpa dem. Måste jag byta bank för det?
#
# Preprocessed tweet:
#  <id> varför ska det vara så förtvivlat svårt att i egenskap av privatperson handla fonder med fokus på klimat och förnybar energi de få fonder jag hittar ger felmeddelande att endast professionella placerare får köpa dem måste jag byta bank för det
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.07818019 0.50044414 0.42137567]
#
# Prediction: 	 0
# label 		 -1
#
# -------------------------
#
# Original tweet:
# Attans. Jag är 4 år o 3 dagar försent ute <URL>
#
# Preprocessed tweet:
#  attans jag är 4 år o 3 dagar försent ute <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.13474991 0.69060501 0.17464508]
#
# Prediction: 	 0
# label 		 -1
#
# -------------------------
#
# Original tweet:
# Sorgligt men förmodligen mycket sant  <URL>
#
# Preprocessed tweet:
#  sorgligt men förmodligen mycket sant <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.18955754 0.35006483 0.46037763]
#
# Prediction: 	 1
# label 		 -1
#
# -------------------------
#
# Original tweet:
# Såg nyss ett 20tal män från svenska motstånds rörelsen vid Uni i Stockholm De gjorde hitler hälsning till varandra öppet Sverige 2017
#
# Preprocessed tweet:
#  såg nyss ett 20tal män från svenska motstånds rörelsen vid uni i stockholm de gjorde hitler hälsning till varandra öppet sverige 2017
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.09169196 0.45445168 0.45385636]
#
# Prediction: 	 1
# label 		 -1
#
# -------------------------
#
# Original tweet:
# <ID> Skönt ändå att många rensar bort sig själva så snabbt.
#
# Preprocessed tweet:
#  <id> skönt ändå att många rensar bort sig själva så snabbt
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.15274655 0.15286262 0.69439083]
#
# Prediction: 	 1
# label 		 -1
#
# -------------------------
#
# Original tweet:
# <ID> Nu är du väl konspiratorisk. Det var speltorsken i dig som skrev den.
#
# Preprocessed tweet:
#  <id> nu är du väl konspiratorisk det var speltorsken i dig som skrev den
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.28597726 0.52366073 0.19036201]
#
# Prediction: 	 0
# label 		 -1
#
# -------------------------
#
# Original tweet:
# <ID> Ja Tack för det Inte så kaxig precis
#
# Preprocessed tweet:
#  <id> ja tack för det inte så kaxig precis
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.22677078 0.15778096 0.61544826]
#
# Prediction: 	 1
# label 		 -1
#
# -------------------------
#
# Original tweet:
#  På JMG 28 mars - om hat, hot och troll i medierna. Välkommen!. <HASCHTAG> <URL>
#
# Preprocessed tweet:
#  på jmg 28 mars om hat hot och troll i medierna välkommen <haschtag> <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.29554471 0.10303922 0.60141607]
#
# Prediction: 	 1
# label 		 -1
#
# -------------------------
#
# Original tweet:
# <ID> Det är det väl nästan ingen som påstår heller?
#
# Preprocessed tweet:
#  <id> det är det väl nästan ingen som påstår heller
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.29159266 0.65065242 0.05775492]
#
# Prediction: 	 0
# label 		 -1
#
# -------------------------
#
# Original tweet:
# <ID> Att man ens bemöter sånt dravel men orsak till bra utfall vid rekonstruktion och sålda trottoarkant  <URL>
#
# Preprocessed tweet:
#  <id> att man ens bemöter sånt dravel men orsak till bra utfall vid rekonstruktion och sålda trottoarkant <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.22412596 0.33010076 0.44577327]
#
# Prediction: 	 1
# label 		 -1
#
# -------------------------
#
# Original tweet:
# Efterlyses: Mindre käbbel och mer småföretagarpolitik. Hur svårt kan det vara? <HASCHTAG> <URL>
#
# Preprocessed tweet:
#  efterlyses mindre käbbel och mer småföretagarpolitik hur svårt kan det vara <haschtag> <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.29223363 0.62572447 0.0820419 ]
#
# Prediction: 	 0
# label 		 -1
#
# -------------------------
#
# Original tweet:
# BONDE SÖKER FRU ÄR SÅ CRINGE
#
# Preprocessed tweet:
#  bonde söker fru är så cringe
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.17405633 0.40023564 0.42570804]
#
# Prediction: 	 1
# label 		 -1
#
# -------------------------
#
# Original tweet:
# Asylsökande kvinna misstänks ha legat bakom storbrand på boende: <URL> <HASCHTAG>
#
# Preprocessed tweet:
#  asylsökande kvinna misstänks ha legat bakom storbrand på boende <url> <haschtag>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.11201665 0.64074532 0.24723802]
#
# Prediction: 	 0
# label 		 -1
#
# -------------------------
#
# Original tweet:
# Det är precis min känsla Vi vet vilka det är som sysslar med grov brottslighet i gängmiljöer men har inte resurser att punktmarkera
#
# Preprocessed tweet:
#  det är precis min känsla vi vet vilka det är som sysslar med grov brottslighet i gängmiljöer men har inte resurser att punktmarkera
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.40118099 0.55122694 0.04759206]
#
# Prediction: 	 0
# label 		 -1
#
# -------------------------
#
# Original tweet:
# Alltså inte ens jag som mamma tar i henne utan hennes medgivande så vad är det med främmande människor
#
# Preprocessed tweet:
#  alltså inte ens jag som mamma tar i henne utan hennes medgivande så vad är det med främmande människor
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.46806839 0.49376045 0.03817115]
#
# Prediction: 	 0
# label 		 -1
#
# -------------------------
#
# Original tweet:
# @Folksam Varför dm? Om jag sitter i närmare en halvtimme i telefonkö och blir bortkopplad?
#
# Digitalisera er, det vore nåt. Tänk om man kunde mata in sitt ärendenr så man hamnade rätt direkt? Nä, det vore ju enkelt.
#
# Preprocessed tweet:
#  <id> varför dm om jag sitter i närmare en halvtimme i telefonkö och blir bortkopplad digitalisera er det vore nåt tänk om man kunde mata in sitt ärendenr så man hamnade rätt direkt nä det vore ju enkelt
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.10102865 0.88129016 0.01768118]
#
# Prediction: 	 0
# label 		 -1
#
# -------------------------
#
# Original tweet:
# Ni vet den klassiska bilden av kvinnan som lagat mat hela kvällen och han blir så jävla sen Ja Det hände nys  <URL>
#
# Preprocessed tweet:
#  ni vet den klassiska bilden av kvinnan som lagat mat hela kvällen och han blir så jävla sen ja det hände nys <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.42285463 0.54216977 0.0349756 ]
#
# Prediction: 	 0
# label 		 -1
#
# -------------------------
#
# Original tweet:
# Blir buggarna det största hotet mot överlevnad även i State of Decay 2? I post-apokalypsen hackar bilduppdateringen oss till döds!
#
# Preprocessed tweet:
#  blir buggarna det största hotet mot överlevnad även i state of decay 2 i post apokalypsen hackar bilduppdateringen oss till döds
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.19956607 0.60608766 0.19434627]
#
# Prediction: 	 0
# label 		 -1
#
# -------------------------
#
# Original tweet:
# Sveriges kung Carl XVI Gustav besökte Örebro moskén efter sorga elden som brinnde största byggnaden i moskén.… <URL>
#
# Preprocessed tweet:
#  sveriges kung carl xvi gustav besökte örebro mosk n efter sorga elden som brinnde största byggnaden i mosk n <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.06473316 0.27060138 0.66466546]
#
# Prediction: 	 1
# label 		 -1
#
# -------------------------
#
# Original tweet:
# <ID> Framför allt kunde den sorgliga siffran vara bättre
#
# Preprocessed tweet:
#  <id> framför allt kunde den sorgliga siffran vara bättre
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.22631005 0.43755792 0.33613204]
#
# Prediction: 	 0
# label 		 -1
#
# -------------------------
#
# Original tweet:
# Stefan Löfven ska demonstrera i Landskrona och Malmö men socialdemokratin saknar skam  <URL> via  <ID>  <HASCHTAG>
#
# Preprocessed tweet:
#  stefan löfven ska demonstrera i landskrona och malmö men socialdemokratin saknar skam <url> via <id> <haschtag>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.11613392 0.25332737 0.63053871]
#
# Prediction: 	 1
# label 		 -1
#
# -------------------------
#
# Original tweet:
# <ID> Exakt Och super man var och varannan dag är man inte ett dugg bättre än dom som tar droger heller oavse  <URL>
#
# Preprocessed tweet:
#  <id> exakt och super man var och varannan dag är man inte ett dugg bättre än dom som tar droger heller oavse <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.09668071 0.48455509 0.41876419]
#
# Prediction: 	 0
# label 		 -1
#
# -------------------------
#
# Original tweet:
# <ID> Om jag varit med ett parti som demonstrerar samtidigt som apologeter till Venezuela och Nordkorea så  <URL>
#
# Preprocessed tweet:
#  <id> om jag varit med ett parti som demonstrerar samtidigt som apologeter till venezuela och nordkorea så <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.07016841 0.84846145 0.08137013]
#
# Prediction: 	 0
# label 		 -1
#
# -------------------------
#
# Original tweet:
#  Rögle har ingen målvakt, men Sveriges fulaste dräkter
#
# Preprocessed tweet:
#  rögle har ingen målvakt men sveriges fulaste dräkter
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.28313328 0.6727377  0.04412903]
#
# Prediction: 	 0
# label 		 -1
#
# -------------------------
#
# Original tweet:
# @trygghansa @Folksam Prob anmäla en vattenskada på ett hus som ägs av ett dödsbo så jag måste prata med någon. Hur kan det vara så att jag ringde 15 - 20 gånger i fredags och 7 gånger idag och svar "vi har många som ringer och kan inte ta emot ditt samtal, ring senare"??? VERKLIGEN usel service!
#
# Preprocessed tweet:
#  <id> prob anmäla en vattenskada på ett hus som ägs av ett dödsbo så jag måste prata med någon hur kan det vara så att jag ringde 15 20 gånger i fredags och 7 gånger idag och svar vi har många som ringer och kan inte ta emot ditt samtal ring senare verkligen usel service
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.44778618 0.54977112 0.0024427 ]
#
# Prediction: 	 0
# label 		 -1
#
# -------------------------
#
# Original tweet:
#  Vad är det med Timrå IK i dag? Otroligt många individuella misstag, många är alldeles för stillastående och inget samarbete över huvudtaget.
#
# Preprocessed tweet:
#  vad är det med timrå ik i dag otroligt många individuella misstag många är alldeles för stillastående och inget samarbete över huvudtaget
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.31095759 0.67011054 0.01893187]
#
# Prediction: 	 0
# label 		 -1
#
# -------------------------
#
# Original tweet:
# @Mariela79377749 @arvidpu @SkandiaSE För de flesta landstingen har utbetalningarna redan börjat minska. Detta är ren marknadsföring från @SkandiaSE
#
# Preprocessed tweet:
#  <id> för de flesta landstingen har utbetalningarna redan börjat minska detta är ren marknadsföring från <id>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.18342187 0.43725155 0.37932658]
#
# Prediction: 	 1
# label 		 -1
#
# -------------------------
#
# Original tweet:
# Kalmar FF Så mycket frågetecken
#
# Preprocessed tweet:
#  kalmar ff så mycket frågetecken
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.33096305 0.50746018 0.16157677]
#
# Prediction: 	 0
# label 		 -1
#
# -------------------------
#
# Original tweet:
# PM klagör nu 0900 att tidigare rapporterat insidersälj är en flytt
#
# Preprocessed tweet:
#  pm klagör nu 0900 att tidigare rapporterat insidersälj är en flytt
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.32685761 0.30699955 0.36614284]
#
# Prediction: 	 1
# label 		 -1
#
# -------------------------
#
# Original tweet:
# Linnér hit och dit. Varför står hela laget på hälarna i eget straffområde från paus till deras kvittering? Såg ju lika illa ut mot Kalmar.
#
# Preprocessed tweet:
#  linn r hit och dit varför står hela laget på hälarna i eget straffområde från paus till deras kvittering såg ju lika illa ut mot kalmar
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.12543232 0.8490569  0.02551078]
#
# Prediction: 	 0
# label 		 -1
#
# -------------------------
#
# Original tweet:
# Tycker det är bull om Johan Hammar hamnar i Häcken men bättre än hif eller ifkg såklart.
#
# Preprocessed tweet:
#  tycker det är bull om johan hammar hamnar i häcken men bättre än hif eller ifkg såklart
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.25744313 0.41661429 0.32594258]
#
# Prediction: 	 0
# label 		 -1
#
# -------------------------
#
# Original tweet:
#  <ID> Bittra onödiga poängtapp där... O andra sidan skulle LFC avgjort redan i första, på de chanser de hade… <URL>
#
# Preprocessed tweet:
#  <id> bittra onödiga poängtapp där o andra sidan skulle lfc avgjort redan i första på de chanser de hade <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.13792681 0.63576831 0.22630488]
#
# Prediction: 	 0
# label 		 -1
#
# -------------------------
#
# Original tweet:
# Snöflingor förhindrade fascister från att mötas  <URL>
#
# Preprocessed tweet:
#  snöflingor förhindrade fascister från att mötas <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.20965179 0.5824949  0.20785331]
#
# Prediction: 	 0
# label 		 -1
#
# -------------------------
#
# Original tweet:
# Hemmasittares mamma hotas med vite  Skolvärlden  <URL>
#
# Preprocessed tweet:
#  hemmasittares mamma hotas med vite skolvärlden <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.12614506 0.68144372 0.19241122]
#
# Prediction: 	 0
# label 		 -1
#
# -------------------------
#
# Original tweet:
# <ID>  <ID>  <ID> Som vanligt är det alltid nån annan än sv antirasistiska vänsterfeminister som ska föra feministiska
#
# Preprocessed tweet:
#  <id> som vanligt är det alltid nån annan än sv antirasistiska vänsterfeminister som ska föra feministiska
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.19093911 0.72301559 0.0860453 ]
#
# Prediction: 	 0
# label 		 -1
#
# -------------------------
#
# Original tweet:
# Hur länge ska klassförrädarna få vara kvar och leda S??? <URL> <HASCHTAG> Järva <HASCHTAG>
#
# Preprocessed tweet:
#  hur länge ska klassförrädarna få vara kvar och leda s <url> <haschtag> järva <haschtag>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.07772995 0.554342   0.36792805]
#
# Prediction: 	 0
# label 		 -1
#
# -------------------------
#
# Original tweet:
# 69 Haha du fattar inte en friendzone fett synd det blir stelt
#
# Preprocessed tweet:
#  69 haha du fattar inte en friendzone fett synd det blir stelt
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.44586481 0.48663506 0.06750014]
#
# Prediction: 	 0
# label 		 -1
#
# -------------------------
#
# Original tweet:
# Nej Josefin Utas så vill vi inte ha det! Eller så borde vi inte vilja ha det alls utan i stället motarbeta så... <URL>
#
# Preprocessed tweet:
#  nej josefin utas så vill vi inte ha det eller så borde vi inte vilja ha det alls utan i stället motarbeta så <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.41399396 0.53003705 0.05596899]
#
# Prediction: 	 0
# label 		 -1
#
# -------------------------
#
# Original tweet:
# Det här är den konstigaste artikeln jag har läst på länge Kan NÅGON deschiffrera  <URL>
#
# Preprocessed tweet:
#  det här är den konstigaste artikeln jag har läst på länge kan någon deschiffrera <url>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.3521317  0.48325395 0.16461436]
#
# Prediction: 	 0
# label 		 -1
#
# -------------------------
#
# Original tweet:
# Denna borgerliga passion för sänkta löner är ofattbar. Även enkla jobb kan utföras till schyssta löner. <HASCHTAG>
#
# Preprocessed tweet:
#  denna borgerliga passion för sänkta löner är ofattbar även enkla jobb kan utföras till schyssta löner <haschtag>
#
# Probabilities:
#     neg 	 neu 	   pos
# [0.30747279 0.4383097  0.25421751]
#
# Prediction: 	 0
# label 		 -1
#
# -------------------------

# %% [markdown]
# ## Save model
#
# ### The two crucial parts are the model itself and the word2index mapper.

# %%
import os
import pickle


def save_model(path, model, prob_model, w2i):
    dir_name = path.split('.')[0]
    if not os.path.exists(dir_name):
        os.mkdir(dir_name)
    else:
        print('Error: \nChoose different model name for saving, as a folder with that name already exists')
        return
    
    model_path = os.path.join(dir_name, path)
    prob_model_path = os.path.join(dir_name, 'prob_'+path)
    w2i_path = os.path.join(dir_name, 'word2index.pkl')
    init_path = os.path.join(dir_name, '__init__.py')
    
    save_pickle(model_path, model)
    save_pickle(prob_model_path, prob_model)
    save_pickle(w2i_path, w2i)
    
    f = open(init_path, 'w')
    f.close()
    
def save_pickle(path, obj):
    with open(path, 'wb') as f:
        pickle.dump(obj, f)
        
    return

# %% [markdown]
# ### Where to save the model?

# %%
model_save_path = 'linear_svm.pkl' # Must be a .pkl file extension name!


save_model(model_save_path, clf_linear, clf_calibrated, word2index)

# %% [markdown]
# ## RBF-kernel SVM (Non-linear)

# %%
from sklearn.svm import SVC
clf_svc = SVC(C=15, gamma=1e-2, verbose=9)

# %%
clf_svc.fit(train_x_vectorized, train_Y)
# Out:
# [LibSVM]
# SVC(C=15, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=9)

# %%
print()
print("Detailed classification report:")
print()
print("The model is trained on the full development set.")
print("The scores are computed on the full evaluation set.")

y_true, y_pred = test_Y, clf_svc.predict(test_x_vectorized)

print(classification_report(y_true, y_pred))
print()
print('Accuracy on test/evaluation set: ', accuracy_score(y_true, y_pred))
print()
print('Confusion matrix:')
print(confusion_matrix(y_true, y_pred))
# Out:
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#               precision    recall  f1-score   support
#
#           -1       0.57      0.68      0.62       336
#            0       0.56      0.49      0.52       336
#            1       0.73      0.68      0.71       336
#
#    micro avg       0.62      0.62      0.62      1008
#    macro avg       0.62      0.62      0.62      1008
# weighted avg       0.62      0.62      0.62      1008
#
#
# Accuracy on test/evaluation set:  0.6170634920634921
#
# Confusion matrix:
# [[228  72  36]
#  [123 165  48]
#  [ 47  60 229]]

# %%
print(y_pred)
